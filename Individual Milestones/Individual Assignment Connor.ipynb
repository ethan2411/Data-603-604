# %% [markdown]
# ## Data Cleaning/Wrangling

# %% [markdown]
# Some initial data wrangling and cleaning was conducted before inserting the data. All NaN values were removed since MariaDB only accepts null values which are not NaN so we were getting errors when trying to inserrt data will NaN values so in the end we decided to remove all missing values before hand. Secondly, as you can see below, the data was loaded separately from 9 different CSV files. This is because of the massive size of this data set being around 550,000. On top of that it contained multipolygon coordinate data so it massively increased the size of the files. Because of this we ended up removing the multipolygon column before inserting our data because we did not plan on using this column in the end anyways. This vastly cut down on the time it took for inserting our data (I tried inserting the data before with the multipolygon column and it was still running after 2 hours). To also be able to load our data into the jupyter notebook cloud without it crashing and to insert it into a database in a much quicker time we took a random sample of the property assessment dataset. After loading all 9 different CSV's into eachother, we merged them into one dataset and then took a random sample of 200000 rows, saved it as a CSV so that we could always go back to it (since the data at this point stays the same and doesnt get randomized ever again). We chose 200000 rows for our sample size since we felt that it was still a large amount of data to use to accurately answer our guiding questions.

# %%
#import libraries

import pandas as pd
import numpy as np

# %%
#Loaded in initial csv files separately so that the cloud kernel would not crash and restart

Property1 = pd.read_csv("Historical_Property_Assessments__Parcel_-1.csv")
Property2 = pd.read_csv("Historical_Property_Assessments__Parcel_-2.csv")
Property3 = pd.read_csv("Historical_Property_Assessments__Parcel_-3.csv")
Property4 = pd.read_csv("Historical_Property_Assessments__Parcel_-4.csv")
Property5 = pd.read_csv("Historical_Property_Assessments__Parcel_-5.csv")
Property6 = pd.read_csv("Historical_Property_Assessments__Parcel_-6.csv")
Property7 = pd.read_csv("Historical_Property_Assessments__Parcel_-7.csv")
Property8 = pd.read_csv("Historical_Property_Assessments__Parcel_-8.csv")
Property9 = pd.read_csv("Historical_Property_Assessments__Parcel_-9.csv")

# %%
#checked which columns had NaN values present and how many were present 

display(Property1.isna().sum())
display(Property2.isna().sum())
display(Property3.isna().sum())
display(Property4.isna().sum())
display(Property5.isna().sum())
display(Property6.isna().sum())
display(Property7.isna().sum())
display(Property8.isna().sum())
display(Property9.isna().sum())
# Out:
# ROLL_YEAR                           0
# ROLL_NUMBER                         0
# ADDRESS                             0
# ASSESSED_VALUE                      0
# ASSESSMENT_CLASS_DESCRIPTION        0
# RE_ASSESSED_VALUE                  24
# FL_ASSESSED_VALUE               72411
# COMM_CODE                           0
# COMM_NAME                           0
# YEAR_OF_CONSTRUCTION            72411
# LAND_USE_DESIGNATION                8
# PROPERTY_TYPE                       0
# LAND_SIZE_SM                        8
# LAND_SIZE_SF                        8
# LAND_SIZE_AC                        8
# SUB_PROPERTY_USE                71054
# MULTIPOLYGON                        0
# dtype: int64
# ROLL_YEAR                           0
# ROLL_NUMBER                         0
# ADDRESS                             3
# ASSESSED_VALUE                      0
# ASSESSMENT_CLASS_DESCRIPTION        0
# RE_ASSESSED_VALUE                  80
# FL_ASSESSED_VALUE               68926
# COMM_CODE                           0
# COMM_NAME                           0
# YEAR_OF_CONSTRUCTION            68924
# LAND_USE_DESIGNATION                5
# PROPERTY_TYPE                       0
# LAND_SIZE_SM                        5
# LAND_SIZE_SF                        5
# LAND_SIZE_AC                        5
# SUB_PROPERTY_USE                61771
# MULTIPOLYGON                        0
# dtype: int64
# ROLL_YEAR                           0
# ROLL_NUMBER                         0
# ADDRESS                             0
# ASSESSED_VALUE                      0
# ASSESSMENT_CLASS_DESCRIPTION        0
# RE_ASSESSED_VALUE                  73
# FL_ASSESSED_VALUE               71513
# COMM_CODE                           0
# COMM_NAME                           0
# YEAR_OF_CONSTRUCTION            71511
# LAND_USE_DESIGNATION                3
# PROPERTY_TYPE                       0
# LAND_SIZE_SM                        3
# LAND_SIZE_SF                        3
# LAND_SIZE_AC                        3
# SUB_PROPERTY_USE                69714
# MULTIPOLYGON                        0
# dtype: int64
# ROLL_YEAR                           0
# ROLL_NUMBER                         0
# ADDRESS                             0
# ASSESSED_VALUE                      0
# ASSESSMENT_CLASS_DESCRIPTION        0
# RE_ASSESSED_VALUE                  40
# FL_ASSESSED_VALUE               63193
# COMM_CODE                           0
# COMM_NAME                           0
# YEAR_OF_CONSTRUCTION            63201
# LAND_USE_DESIGNATION                0
# PROPERTY_TYPE                       0
# LAND_SIZE_SM                        0
# LAND_SIZE_SF                        0
# LAND_SIZE_AC                        0
# SUB_PROPERTY_USE                57786
# MULTIPOLYGON                        0
# dtype: int64
# ROLL_YEAR                           0
# ROLL_NUMBER                         0
# ADDRESS                             0
# ASSESSED_VALUE                      0
# ASSESSMENT_CLASS_DESCRIPTION        0
# RE_ASSESSED_VALUE                  38
# FL_ASSESSED_VALUE               54336
# COMM_CODE                           0
# COMM_NAME                           0
# YEAR_OF_CONSTRUCTION            54357
# LAND_USE_DESIGNATION                3
# PROPERTY_TYPE                       0
# LAND_SIZE_SM                        3
# LAND_SIZE_SF                        3
# LAND_SIZE_AC                        3
# SUB_PROPERTY_USE                44331
# MULTIPOLYGON                        0
# dtype: int64
# ROLL_YEAR                           0
# ROLL_NUMBER                         0
# ADDRESS                             0
# ASSESSED_VALUE                      0
# ASSESSMENT_CLASS_DESCRIPTION        0
# RE_ASSESSED_VALUE                  23
# FL_ASSESSED_VALUE               53976
# COMM_CODE                           0
# COMM_NAME                           0
# YEAR_OF_CONSTRUCTION            54061
# LAND_USE_DESIGNATION               11
# PROPERTY_TYPE                       0
# LAND_SIZE_SM                        0
# LAND_SIZE_SF                        0
# LAND_SIZE_AC                        0
# SUB_PROPERTY_USE                41794
# MULTIPOLYGON                        0
# dtype: int64
# ROLL_YEAR                           0
# ROLL_NUMBER                         0
# ADDRESS                             0
# ASSESSED_VALUE                      0
# ASSESSMENT_CLASS_DESCRIPTION        0
# RE_ASSESSED_VALUE                  29
# FL_ASSESSED_VALUE               41068
# COMM_CODE                           0
# COMM_NAME                           0
# YEAR_OF_CONSTRUCTION            41070
# LAND_USE_DESIGNATION                0
# PROPERTY_TYPE                       0
# LAND_SIZE_SM                        0
# LAND_SIZE_SF                        0
# LAND_SIZE_AC                        0
# SUB_PROPERTY_USE                31564
# MULTIPOLYGON                        0
# dtype: int64
# ROLL_YEAR                           0
# ROLL_NUMBER                         0
# ADDRESS                             0
# ASSESSED_VALUE                      0
# ASSESSMENT_CLASS_DESCRIPTION        0
# RE_ASSESSED_VALUE                  45
# FL_ASSESSED_VALUE               40387
# COMM_CODE                           0
# COMM_NAME                           0
# YEAR_OF_CONSTRUCTION            40406
# LAND_USE_DESIGNATION                4
# PROPERTY_TYPE                       0
# LAND_SIZE_SM                        4
# LAND_SIZE_SF                        4
# LAND_SIZE_AC                        4
# SUB_PROPERTY_USE                29907
# MULTIPOLYGON                        0
# dtype: int64
# ROLL_YEAR                           0
# ROLL_NUMBER                         0
# ADDRESS                             0
# ASSESSED_VALUE                      0
# ASSESSMENT_CLASS_DESCRIPTION        0
# RE_ASSESSED_VALUE                  15
# FL_ASSESSED_VALUE               53921
# COMM_CODE                           0
# COMM_NAME                           0
# YEAR_OF_CONSTRUCTION            53961
# LAND_USE_DESIGNATION                9
# PROPERTY_TYPE                       0
# LAND_SIZE_SM                        5
# LAND_SIZE_SF                        5
# LAND_SIZE_AC                        5
# SUB_PROPERTY_USE                51517
# MULTIPOLYGON                        0
# dtype: int64

# %%
#Cleaning the dataframes to get rid of nan values so we can load it into the database

#make a list containing all our dataframes
frames = [Property1, Property2, Property3, Property4, Property5, Property6, Property7, Property8, Property9]

#make a list of the columns where we want to drop any of the rows that have NaN values in these columns
na_rows_to_drop = ["LAND_USE_DESIGNATION", "LAND_SIZE_SM", "LAND_SIZE_SF", "LAND_SIZE_AC","ADDRESS"]

#make a list of the columns we want to drop because the majority of the column contains NaN values or the column is undesired such as geo/multipolygon data (since it is insanely large and crashes loading into the db, we dont need it anyways). 
columns_to_drop = ["FL_ASSESSED_VALUE","YEAR_OF_CONSTRUCTION", "SUB_PROPERTY_USE", "PROPERTY_TYPE", "RE_ASSESSED_VALUE", "MULTIPOLYGON"]

#loop through all our 9 dataframes
for dataset in frames:
    #drop any rows containing NaN values from the columns where we saw NaN values to be present (we only are doing this with the columns that we want to keep and only have a small amount of NaN values)
    for col in na_rows_to_drop:
        dataset.dropna(subset=[col], inplace=True)
        
    #drop all unnecesarry columns that we are not going to be using (drop columns with the majority of the data being NaN values and also columns that are non-desired)
    for col in columns_to_drop:
        dataset.drop(col, axis = 1, inplace = True)

# %%
#check if there are any more remaining NaN values present in any of the 9 datasets
display(Property1.isna().sum())
display(Property2.isna().sum())
display(Property3.isna().sum())
display(Property4.isna().sum())
display(Property5.isna().sum())
display(Property6.isna().sum())
display(Property7.isna().sum())
display(Property8.isna().sum())
display(Property9.isna().sum())

#we can see that there are no NaN values present so we are ready to insert the data into a database
# Out:
# ROLL_YEAR                       0
# ROLL_NUMBER                     0
# ADDRESS                         0
# ASSESSED_VALUE                  0
# ASSESSMENT_CLASS_DESCRIPTION    0
# COMM_CODE                       0
# COMM_NAME                       0
# LAND_USE_DESIGNATION            0
# LAND_SIZE_SM                    0
# LAND_SIZE_SF                    0
# LAND_SIZE_AC                    0
# dtype: int64
# ROLL_YEAR                       0
# ROLL_NUMBER                     0
# ADDRESS                         0
# ASSESSED_VALUE                  0
# ASSESSMENT_CLASS_DESCRIPTION    0
# COMM_CODE                       0
# COMM_NAME                       0
# LAND_USE_DESIGNATION            0
# LAND_SIZE_SM                    0
# LAND_SIZE_SF                    0
# LAND_SIZE_AC                    0
# dtype: int64
# ROLL_YEAR                       0
# ROLL_NUMBER                     0
# ADDRESS                         0
# ASSESSED_VALUE                  0
# ASSESSMENT_CLASS_DESCRIPTION    0
# COMM_CODE                       0
# COMM_NAME                       0
# LAND_USE_DESIGNATION            0
# LAND_SIZE_SM                    0
# LAND_SIZE_SF                    0
# LAND_SIZE_AC                    0
# dtype: int64
# ROLL_YEAR                       0
# ROLL_NUMBER                     0
# ADDRESS                         0
# ASSESSED_VALUE                  0
# ASSESSMENT_CLASS_DESCRIPTION    0
# COMM_CODE                       0
# COMM_NAME                       0
# LAND_USE_DESIGNATION            0
# LAND_SIZE_SM                    0
# LAND_SIZE_SF                    0
# LAND_SIZE_AC                    0
# dtype: int64
# ROLL_YEAR                       0
# ROLL_NUMBER                     0
# ADDRESS                         0
# ASSESSED_VALUE                  0
# ASSESSMENT_CLASS_DESCRIPTION    0
# COMM_CODE                       0
# COMM_NAME                       0
# LAND_USE_DESIGNATION            0
# LAND_SIZE_SM                    0
# LAND_SIZE_SF                    0
# LAND_SIZE_AC                    0
# dtype: int64
# ROLL_YEAR                       0
# ROLL_NUMBER                     0
# ADDRESS                         0
# ASSESSED_VALUE                  0
# ASSESSMENT_CLASS_DESCRIPTION    0
# COMM_CODE                       0
# COMM_NAME                       0
# LAND_USE_DESIGNATION            0
# LAND_SIZE_SM                    0
# LAND_SIZE_SF                    0
# LAND_SIZE_AC                    0
# dtype: int64
# ROLL_YEAR                       0
# ROLL_NUMBER                     0
# ADDRESS                         0
# ASSESSED_VALUE                  0
# ASSESSMENT_CLASS_DESCRIPTION    0
# COMM_CODE                       0
# COMM_NAME                       0
# LAND_USE_DESIGNATION            0
# LAND_SIZE_SM                    0
# LAND_SIZE_SF                    0
# LAND_SIZE_AC                    0
# dtype: int64
# ROLL_YEAR                       0
# ROLL_NUMBER                     0
# ADDRESS                         0
# ASSESSED_VALUE                  0
# ASSESSMENT_CLASS_DESCRIPTION    0
# COMM_CODE                       0
# COMM_NAME                       0
# LAND_USE_DESIGNATION            0
# LAND_SIZE_SM                    0
# LAND_SIZE_SF                    0
# LAND_SIZE_AC                    0
# dtype: int64
# ROLL_YEAR                       0
# ROLL_NUMBER                     0
# ADDRESS                         0
# ASSESSED_VALUE                  0
# ASSESSMENT_CLASS_DESCRIPTION    0
# COMM_CODE                       0
# COMM_NAME                       0
# LAND_USE_DESIGNATION            0
# LAND_SIZE_SM                    0
# LAND_SIZE_SF                    0
# LAND_SIZE_AC                    0
# dtype: int64

# %%
#merge all our separate cleaned/wrangled csvs into one so we can grab a sample from it and then insert it into the database 
frames = [Property1, Property2, Property3, Property4, Property5, Property6, Property7, Property8, Property9]

Property_Full = pd.concat(frames)

display(Property_Full)
# Out:
#        ROLL_YEAR  ROLL_NUMBER              ADDRESS  ASSESSED_VALUE  \
# 1           2019      4032504  52 SADDLEBACK WY NE          360000
# 2           2019      4032603  48 SADDLEBACK WY NE          366000
# 3           2019      4032702  10 SADDLEBACK RD NE          404000
# 4           2019      4032801  14 SADDLEBACK RD NE          385500
# 5           2019      4032900  18 SADDLEBACK RD NE          395000
# ...          ...          ...                  ...             ...
# 53956       2019    792044703   130 CRANWELL CL SE          488000
# 53957       2019    792044802   126 CRANWELL CL SE          495000
# 53958       2019    792044901   122 CRANWELL CL SE          523000
# 53959       2019    814002002       20606 56 ST SE         1910000
# 53960       2019    857001002       21909 72 ST SE          460000
#
#       ASSESSMENT_CLASS_DESCRIPTION COMM_CODE                        COMM_NAME  \
# 1                      Residential       SAD                     SADDLE RIDGE
# 2                      Residential       SAD                     SADDLE RIDGE
# 3                      Residential       SAD                     SADDLE RIDGE
# 4                      Residential       SAD                     SADDLE RIDGE
# 5                      Residential       SAD                     SADDLE RIDGE
# ...                            ...       ...                              ...
# 53956                  Residential       CRA                         CRANSTON
# 53957                  Residential       CRA                         CRANSTON
# 53958                  Residential       CRA                         CRANSTON
# 53959                  Residential       12F  RESIDUAL WARD 12 - SUB AREA 12F
# 53960                  Residential       12I  RESIDUAL WARD 12 - SUB AREA 12I
#
#                     LAND_USE_DESIGNATION  LAND_SIZE_SM  LAND_SIZE_SF  \
# 1                                   R-1N         310.0        3337.0
# 2                                   R-1N         391.4        4214.0
# 3                                   R-1N         340.0        3659.0
# 4                                   R-1N         347.5        3741.0
# 5                                   R-1N         317.6        3419.0
# ...                                  ...           ...           ...
# 53956                                R-1         451.0        4855.0
# 53957                                R-1         438.2        4717.0
# 53958                                R-1         484.6        5216.0
# 53959  S-FUD,S-SPR,C-C1,M-1,S-R,R-G,R-Gm      647184.6     6966465.0
# 53960                               ANRI      352070.0     3789774.0
#
#        LAND_SIZE_AC
# 1              0.08
# 2              0.10
# 3              0.08
# 4              0.09
# 5              0.08
# ...             ...
# 53956          0.11
# 53957          0.11
# 53958          0.12
# 53959        159.93
# 53960         87.00
#
# [519861 rows x 11 columns]

# %%
#take a sample of the massive combined dataset so that the data can be inserted int othe database at a quicker pace

#Note: I commented this entire cell out because I did not want to accidetally run it again since we did not want to keep grabbing different samples
#I tried setting the seed, however that still did not stop from the sample being different every time. We also checked to see if the sample contained the same amount of unique community codes and we found it contained 249 of 260 community codes. We checked to see which codes were not present and they ended up being residual ward areas so not even communities (we did not plan on using these anyways so there was no issue in them missing)

#import random

#random.seed(2023)

#Property_Data = Property_Full.sample(200000)

#display(Property_Full["COMM_CODE"].nunique())
#display(Property_Data["COMM_CODE"].nunique())

#display(Property_Data)
# Out:
# 260
# 249

# %%
#Take our sample dataset that was made and save it as a CSV file so that the data would not be changed and would forever be saved in case we had issues and needed to go back to the specific data we are using. 

#Property_Data.to_csv("PropertyData.csv", index=False)

# %%
import pandas as pd

Property_Assessment_Data = pd.read_csv("PropertyData.csv")

display(Property_Assessment_Data)
# Out:
#         ROLL_YEAR  ROLL_NUMBER                       ADDRESS  ASSESSED_VALUE  \
# 0            2019     67946327             312 1040 15 AV SW          228500
# 1            2019    202249132             302 1720 10 ST SW          254000
# 2            2019     79582243             2320 ERLTON PL SW          616000
# 3            2019    201219904  2406 11811 LAKE FRASER DR SE          186000
# 4            2019    200571818            169 EVERSYDE CM SW          302500
# ...           ...          ...                           ...             ...
# 199995       2019    104017405             6323 LOUISE RD SW          626000
# 199996       2019    202508461               1 1616 15 AV SW          660000
# 199997       2019    154012405           871 PARKRIDGE RD SE          569500
# 199998       2019    128057205             152 BRAXTON PL SW          450000
# 199999       2019    177016201              44 EDFORTH RD NW          525500
#
#        ASSESSMENT_CLASS_DESCRIPTION COMM_CODE          COMM_NAME  \
# 0                       Residential       BLN           BELTLINE
# 1                       Residential       LMR  LOWER MOUNT ROYAL
# 2                       Residential       ERL             ERLTON
# 3                       Residential       LKB     LAKE BONAVISTA
# 4                       Residential       EVE          EVERGREEN
# ...                             ...       ...                ...
# 199995                  Residential       LKV           LAKEVIEW
# 199996                  Residential       SNA            SUNALTA
# 199997                  Residential       PKL           PARKLAND
# 199998                  Residential       BRA           BRAESIDE
# 199999                  Residential       EDG           EDGEMONT
#
#              LAND_USE_DESIGNATION  LAND_SIZE_SM  LAND_SIZE_SF  LAND_SIZE_AC
# 0                           CC-MH        1010.0       10871.0          0.25
# 1                            M-C2        1615.8       17393.0          0.40
# 2                        M-CG d87         106.5        1147.0          0.03
# 3       DC (pre 1P2007),M-H1 d247       22509.6      242299.0          5.56
# 4                         M-G d44         123.0        1324.0          0.03
# ...                           ...           ...           ...           ...
# 199995                       R-C1         611.5        6583.0          0.15
# 199996                  M-CG d111         603.7        6498.0          0.15
# 199997                       R-C1         592.4        6376.0          0.15
# 199998                       R-C1         897.6        9662.0          0.22
# 199999                       R-C1         461.5        4967.0          0.11
#
# [200000 rows x 11 columns]

# %% [markdown]
# ## Inserting Data into our Database

# %% [markdown]
# After briefly cleaning/wrangling our data, we made the database table and inserted our data as seen below

# %%
import mysql.connector
from mysql.connector import errorcode

filepath = "C:\Users\chore\Documents\Data Science\DATA 604\mariadbpassword.txt"

with open(filepath) as f:
    passw = f.read()

#attempt a connection
myconnection = mysql.connector.connect(user="connor_horemans", 
                                       password=passw,
                                       host="datasciencedb2.ucalgary.ca", 
                                       database="connor_horemans",
                                       allow_local_infile=True)
myconnection

# %%
# CREATE TABLE STATEMENT
create_statement = '''create table connor_horemans.property_data (
    ROLL_YEAR int,
    ROLL_NUMBER int,
    ADDRESS varchar(1000), 
    ASSESSED_VALUE int,
    ASSESSMENT_CLASS_DESCRIPTION varchar(15),
    COMM_CODE varchar(3),
    COMM_NAME varchar(250),
    LAND_USE_DESIGNATION varchar(1000),
    LAND_SIZE_SM float,
    LAND_SIZE_SF float, 
    LAND_SIZE_AC float
    );'''

# now we'll create a cursor and run our create statement
create_cursor = myconnection.cursor()
try:
    create_cursor.execute(create_statement)
except mysql.connector.Error as err:
    if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
        print("Ooops! We already have that table")
    else:
        print(err.msg)
else:
    print("table created successfully!")

create_cursor.close()
# Out:
# Ooops! We already have that table
# True

# %%
#insert our data into the table we made above

insertCursor = myconnection.cursor()

columnString = "`,`".join([str(currentColumn) for currentColumn in Property_Assessment_Data.columns.tolist()])
#print (columnString)

# inserting rows one by one from the DataFrame
for i, currentRow in Property_Assessment_Data.iterrows():
    insertCommand = "INSERT INTO `property_data` (`" + columnString + "`) VALUES (" + "%s,"*(len(currentRow)-1) + "%s)"
    insertCursor.execute(insertCommand, tuple(currentRow))
    
myconnection.commit()

insertCursor.close()
# Out:
# True

# %%
#DELETE TABLE IF NEEDED. DO NOT RUN IF NOT REQUIRED.

deletecursor = myconnection.cursor()
sql = "DROP TABLE IF EXISTS property_data;""
deletecursor.execute(sql)
deletecursor.close()
# Out:
# True

# %% [markdown]
# ## Queries

# %% [markdown]
# The comments on why we chose each of these queries are below each of the individual query cells (so the comment below a specific query explains that one query only)

# %% [markdown]
# ## Query 1

# %%
#Get unique Community Names and Codes

read_cursor = myconnection.cursor(buffered=True, dictionary=True)

query_string = ("SELECT DISTINCT COMM_CODE, COMM_NAME FROM property_data ORDER BY COMM_NAME ASC;")

read_cursor.execute(query_string)

for (prop_value) in read_cursor:
    print(prop_value)
    
read_cursor.close()
# Out:
# {'COMM_CODE': 'ABB', 'COMM_NAME': 'ABBEYDALE'}
# {'COMM_CODE': 'ACA', 'COMM_NAME': 'ACADIA'}
# {'COMM_CODE': 'ALB', 'COMM_NAME': 'ALBERT PARK/RADISSON HEIGHTS'}
# {'COMM_CODE': 'ALT', 'COMM_NAME': 'ALTADORE'}
# {'COMM_CODE': 'AYB', 'COMM_NAME': 'ALYTH/BONNYBROOK'}
# {'COMM_CODE': 'APP', 'COMM_NAME': 'APPLEWOOD PARK'}
# {'COMM_CODE': 'ARB', 'COMM_NAME': 'ARBOUR LAKE'}
# {'COMM_CODE': 'ASP', 'COMM_NAME': 'ASPEN WOODS'}
# {'COMM_CODE': 'AUB', 'COMM_NAME': 'AUBURN BAY'}
# {'COMM_CODE': 'BNF', 'COMM_NAME': 'BANFF TRAIL'}
# {'COMM_CODE': 'BNK', 'COMM_NAME': 'BANKVIEW'}
# {'COMM_CODE': 'BYV', 'COMM_NAME': 'BAYVIEW'}
# {'COMM_CODE': 'BED', 'COMM_NAME': 'BEDDINGTON HEIGHTS'}
# {'COMM_CODE': 'BEL', 'COMM_NAME': 'BEL-AIRE'}
# {'COMM_CODE': 'BLM', 'COMM_NAME': 'BELMONT'}
# {'COMM_CODE': 'BLN', 'COMM_NAME': 'BELTLINE'}
# {'COMM_CODE': 'BVD', 'COMM_NAME': 'BELVEDERE'}
# {'COMM_CODE': 'BDO', 'COMM_NAME': 'BONAVISTA DOWNS'}
# {'COMM_CODE': 'BOW', 'COMM_NAME': 'BOWNESS'}
# {'COMM_CODE': 'BRA', 'COMM_NAME': 'BRAESIDE'}
# {'COMM_CODE': 'BRE', 'COMM_NAME': 'BRENTWOOD'}
# {'COMM_CODE': 'BRD', 'COMM_NAME': 'BRIDGELAND/RIVERSIDE'}
# {'COMM_CODE': 'BRI', 'COMM_NAME': 'BRIDLEWOOD'}
# {'COMM_CODE': 'BRT', 'COMM_NAME': 'BRITANNIA'}
# {'COMM_CODE': 'CAM', 'COMM_NAME': 'CAMBRIAN HEIGHTS'}
# {'COMM_CODE': 'CAN', 'COMM_NAME': 'CANYON MEADOWS'}
# {'COMM_CODE': 'CAP', 'COMM_NAME': 'CAPITOL HILL'}
# {'COMM_CODE': 'CAR', 'COMM_NAME': 'CARRINGTON'}
# {'COMM_CODE': 'CAS', 'COMM_NAME': 'CASTLERIDGE'}
# {'COMM_CODE': 'CED', 'COMM_NAME': 'CEDARBRAE'}
# {'COMM_CODE': 'CHA', 'COMM_NAME': 'CHAPARRAL'}
# {'COMM_CODE': 'CHW', 'COMM_NAME': 'CHARLESWOOD'}
# {'COMM_CODE': 'CHN', 'COMM_NAME': 'CHINATOWN'}
# {'COMM_CODE': 'CHK', 'COMM_NAME': 'CHINOOK PARK'}
# {'COMM_CODE': 'CHR', 'COMM_NAME': 'CHRISTIE PARK'}
# {'COMM_CODE': 'CIT', 'COMM_NAME': 'CITADEL'}
# {'COMM_CODE': 'CSC', 'COMM_NAME': 'CITYSCAPE'}
# {'COMM_CODE': 'CLI', 'COMM_NAME': 'CLIFF BUNGALOW'}
# {'COMM_CODE': 'COA', 'COMM_NAME': 'COACH HILL'}
# {'COMM_CODE': 'COL', 'COMM_NAME': 'COLLINGWOOD'}
# {'COMM_CODE': 'CPF', 'COMM_NAME': 'COPPERFIELD'}
# {'COMM_CODE': 'COR', 'COMM_NAME': 'CORAL SPRINGS'}
# {'COMM_CODE': 'CNS', 'COMM_NAME': 'CORNERSTONE'}
# {'COMM_CODE': 'CGR', 'COMM_NAME': 'COUGAR RIDGE'}
# {'COMM_CODE': 'COU', 'COMM_NAME': 'COUNTRY HILLS'}
# {'COMM_CODE': 'CHV', 'COMM_NAME': 'COUNTRY HILLS VILLAGE'}
# {'COMM_CODE': 'COV', 'COMM_NAME': 'COVENTRY HILLS'}
# {'COMM_CODE': 'CRA', 'COMM_NAME': 'CRANSTON'}
# {'COMM_CODE': 'CRE', 'COMM_NAME': 'CRESCENT HEIGHTS'}
# {'COMM_CODE': 'CRM', 'COMM_NAME': 'CRESTMONT'}
# {'COMM_CODE': 'CUR', 'COMM_NAME': 'CURRIE BARRACKS'}
# {'COMM_CODE': 'DAL', 'COMM_NAME': 'DALHOUSIE'}
# {'COMM_CODE': 'DRG', 'COMM_NAME': 'DEER RIDGE'}
# {'COMM_CODE': 'DRN', 'COMM_NAME': 'DEER RUN'}
# {'COMM_CODE': 'DIA', 'COMM_NAME': 'DIAMOND COVE'}
# {'COMM_CODE': 'DIS', 'COMM_NAME': 'DISCOVERY RIDGE'}
# {'COMM_CODE': 'DDG', 'COMM_NAME': 'DOUGLASDALE/GLEN'}
# {'COMM_CODE': 'DOV', 'COMM_NAME': 'DOVER'}
# {'COMM_CODE': 'DNC', 'COMM_NAME': 'DOWNTOWN COMMERCIAL CORE'}
# {'COMM_CODE': 'DNE', 'COMM_NAME': 'DOWNTOWN EAST VILLAGE'}
# {'COMM_CODE': 'DNW', 'COMM_NAME': 'DOWNTOWN WEST END'}
# {'COMM_CODE': 'EAG', 'COMM_NAME': 'EAGLE RIDGE'}
# {'COMM_CODE': 'EAU', 'COMM_NAME': 'EAU CLAIRE'}
# {'COMM_CODE': 'EDG', 'COMM_NAME': 'EDGEMONT'}
# {'COMM_CODE': 'EPK', 'COMM_NAME': 'ELBOW PARK'}
# {'COMM_CODE': 'EYA', 'COMM_NAME': 'ELBOYA'}
# {'COMM_CODE': 'ERI', 'COMM_NAME': 'ERIN WOODS'}
# {'COMM_CODE': 'ERL', 'COMM_NAME': 'ERLTON'}
# {'COMM_CODE': 'EVN', 'COMM_NAME': 'EVANSTON'}
# {'COMM_CODE': 'EVE', 'COMM_NAME': 'EVERGREEN'}
# {'COMM_CODE': 'FAI', 'COMM_NAME': 'FAIRVIEW'}
# {'COMM_CODE': 'FAL', 'COMM_NAME': 'FALCONRIDGE'}
# {'COMM_CODE': 'FHT', 'COMM_NAME': 'FOREST HEIGHTS'}
# {'COMM_CODE': 'FLN', 'COMM_NAME': 'FOREST LAWN'}
# {'COMM_CODE': 'FRA', 'COMM_NAME': 'FRANKLIN'}
# {'COMM_CODE': 'GAG', 'COMM_NAME': 'GARRISON GREEN'}
# {'COMM_CODE': 'GAW', 'COMM_NAME': 'GARRISON WOODS'}
# {'COMM_CODE': 'GLA', 'COMM_NAME': 'GLAMORGAN'}
# {'COMM_CODE': 'GBK', 'COMM_NAME': 'GLENBROOK'}
# {'COMM_CODE': 'GDL', 'COMM_NAME': 'GLENDALE'}
# {'COMM_CODE': 'GPK', 'COMM_NAME': 'GLENMORE PARK'}
# {'COMM_CODE': 'GRV', 'COMM_NAME': 'GREENVIEW'}
# {'COMM_CODE': 'GRI', 'COMM_NAME': 'GREENVIEW INDUSTRIAL PARK'}
# {'COMM_CODE': 'GRE', 'COMM_NAME': 'GREENWOOD/GREENBRIAR'}
# {'COMM_CODE': 'HAM', 'COMM_NAME': 'HAMPTONS'}
# {'COMM_CODE': 'HAR', 'COMM_NAME': 'HARVEST HILLS'}
# {'COMM_CODE': 'HAW', 'COMM_NAME': 'HAWKWOOD'}
# {'COMM_CODE': 'HAY', 'COMM_NAME': 'HAYSBORO'}
# {'COMM_CODE': 'HID', 'COMM_NAME': 'HIDDEN VALLEY'}
# {'COMM_CODE': 'HPK', 'COMM_NAME': 'HIGHLAND PARK'}
# {'COMM_CODE': 'HIW', 'COMM_NAME': 'HIGHWOOD'}
# {'COMM_CODE': 'HIL', 'COMM_NAME': 'HILLHURST'}
# {'COMM_CODE': 'HKS', 'COMM_NAME': 'HOTCHKISS'}
# {'COMM_CODE': 'HOU', 'COMM_NAME': 'HOUNSFIELD HEIGHTS/BRIAR HILL'}
# {'COMM_CODE': 'HUN', 'COMM_NAME': 'HUNTINGTON HILLS'}
# {'COMM_CODE': 'ING', 'COMM_NAME': 'INGLEWOOD'}
# {'COMM_CODE': 'KEL', 'COMM_NAME': 'KELVIN GROVE'}
# {'COMM_CODE': 'KIL', 'COMM_NAME': 'KILLARNEY/GLENGARRY'}
# {'COMM_CODE': 'KCA', 'COMM_NAME': 'KINCORA'}
# {'COMM_CODE': 'KIN', 'COMM_NAME': 'KINGSLAND'}
# {'COMM_CODE': 'LKB', 'COMM_NAME': 'LAKE BONAVISTA'}
# {'COMM_CODE': 'LKV', 'COMM_NAME': 'LAKEVIEW'}
# {'COMM_CODE': 'LEG', 'COMM_NAME': 'LEGACY'}
# {'COMM_CODE': 'LPK', 'COMM_NAME': 'LINCOLN PARK'}
# {'COMM_CODE': 'LIV', 'COMM_NAME': 'LIVINGSTON'}
# {'COMM_CODE': 'LMR', 'COMM_NAME': 'LOWER MOUNT ROYAL'}
# {'COMM_CODE': 'MAC', 'COMM_NAME': 'MACEWAN'}
# {'COMM_CODE': 'MAH', 'COMM_NAME': 'MAHOGANY'}
# {'COMM_CODE': 'MAN', 'COMM_NAME': 'MANCHESTER'}
# {'COMM_CODE': 'MPL', 'COMM_NAME': 'MAPLE RIDGE'}
# {'COMM_CODE': 'MRL', 'COMM_NAME': 'MARLBOROUGH'}
# {'COMM_CODE': 'MPK', 'COMM_NAME': 'MARLBOROUGH PARK'}
# {'COMM_CODE': 'MRT', 'COMM_NAME': 'MARTINDALE'}
# {'COMM_CODE': 'MAF', 'COMM_NAME': 'MAYFAIR'}
# {'COMM_CODE': 'MAL', 'COMM_NAME': 'MAYLAND HEIGHTS'}
# {'COMM_CODE': 'MCK', 'COMM_NAME': 'MCKENZIE LAKE'}
# {'COMM_CODE': 'MCT', 'COMM_NAME': 'MCKENZIE TOWNE'}
# {'COMM_CODE': 'MEA', 'COMM_NAME': 'MEADOWLARK PARK'}
# {'COMM_CODE': 'MDH', 'COMM_NAME': 'MEDICINE HILL'}
# {'COMM_CODE': 'MID', 'COMM_NAME': 'MIDNAPORE'}
# {'COMM_CODE': 'MLR', 'COMM_NAME': 'MILLRISE'}
# {'COMM_CODE': 'MIS', 'COMM_NAME': 'MISSION'}
# {'COMM_CODE': 'MOR', 'COMM_NAME': 'MONTEREY PARK'}
# {'COMM_CODE': 'MON', 'COMM_NAME': 'MONTGOMERY'}
# {'COMM_CODE': 'MOP', 'COMM_NAME': 'MOUNT PLEASANT'}
# {'COMM_CODE': 'NEB', 'COMM_NAME': 'NEW BRIGHTON'}
# {'COMM_CODE': 'NOL', 'COMM_NAME': 'NOLAN HILL'}
# {'COMM_CODE': 'NGM', 'COMM_NAME': 'NORTH GLENMORE PARK'}
# {'COMM_CODE': 'NHV', 'COMM_NAME': 'NORTH HAVEN'}
# {'COMM_CODE': 'NHU', 'COMM_NAME': 'NORTH HAVEN UPPER'}
# {'COMM_CODE': 'OAK', 'COMM_NAME': 'OAKRIDGE'}
# {'COMM_CODE': 'OGD', 'COMM_NAME': 'OGDEN'}
# {'COMM_CODE': 'PAL', 'COMM_NAME': 'PALLISER'}
# {'COMM_CODE': 'PAN', 'COMM_NAME': 'PANORAMA HILLS'}
# {'COMM_CODE': 'PKD', 'COMM_NAME': 'PARKDALE'}
# {'COMM_CODE': 'PKH', 'COMM_NAME': 'PARKHILL/STANLEY PARK'}
# {'COMM_CODE': 'PKL', 'COMM_NAME': 'PARKLAND'}
# {'COMM_CODE': 'PAT', 'COMM_NAME': 'PATTERSON'}
# {'COMM_CODE': 'PEN', 'COMM_NAME': 'PENBROOKE MEADOWS'}
# {'COMM_CODE': 'PCK', 'COMM_NAME': 'PINE CREEK'}
# {'COMM_CODE': 'PIN', 'COMM_NAME': 'PINERIDGE'}
# {'COMM_CODE': 'POI', 'COMM_NAME': 'POINT MCKAY'}
# {'COMM_CODE': 'PUM', 'COMM_NAME': 'PUMP HILL'}
# {'COMM_CODE': 'QPK', 'COMM_NAME': 'QUEENS PARK VILLAGE'}
# {'COMM_CODE': 'QLD', 'COMM_NAME': 'QUEENSLAND'}
# {'COMM_CODE': 'RAM', 'COMM_NAME': 'RAMSAY'}
# {'COMM_CODE': 'RAN', 'COMM_NAME': 'RANCHLANDS'}
# {'COMM_CODE': 'RVW', 'COMM_NAME': 'RANGEVIEW'}
# {'COMM_CODE': 'RED', 'COMM_NAME': 'RED CARPET/MOUNTVIEW MOBILE PARK'}
# {'COMM_CODE': 'RSN', 'COMM_NAME': 'REDSTONE'}
# {'COMM_CODE': 'REN', 'COMM_NAME': 'RENFREW'}
# {'COMM_CODE': '01C', 'COMM_NAME': 'RESIDUAL WARD 1 - CALGARY WEST'}
# {'COMM_CODE': '01D', 'COMM_NAME': 'RESIDUAL WARD 1 - CANADA OLYMPIC PARK'}
# {'COMM_CODE': '01F', 'COMM_NAME': 'RESIDUAL WARD 1 - SUB AREA 1F'}
# {'COMM_CODE': '01H', 'COMM_NAME': 'RESIDUAL WARD 1 - SUB AREA 1H'}
# {'COMM_CODE': '10A', 'COMM_NAME': 'RESIDUAL WARD 10 - SUB AREA 10A'}
# {'COMM_CODE': '10B', 'COMM_NAME': 'RESIDUAL WARD 10 - SUB AREA 10B'}
# {'COMM_CODE': '10C', 'COMM_NAME': 'RESIDUAL WARD 10 - SUB AREA 10C'}
# {'COMM_CODE': '12A', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12A'}
# {'COMM_CODE': '12B', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12B'}
# {'COMM_CODE': '12C', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12C'}
# {'COMM_CODE': '12I', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12I'}
# {'COMM_CODE': '12J', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12J'}
# {'COMM_CODE': '12L', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12L'}
# {'COMM_CODE': '13C', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13C'}
# {'COMM_CODE': '13D', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13D'}
# {'COMM_CODE': '13E', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13E'}
# {'COMM_CODE': '13F', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13F'}
# {'COMM_CODE': '13G', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13G'}
# {'COMM_CODE': '14V', 'COMM_NAME': 'RESIDUAL WARD 14 - SUB AREA 14V'}
# {'COMM_CODE': '02L', 'COMM_NAME': 'RESIDUAL WARD 2 - SUB AREA 02L'}
# {'COMM_CODE': '02C', 'COMM_NAME': 'RESIDUAL WARD 2 - SUB AREA 2C'}
# {'COMM_CODE': '02K', 'COMM_NAME': 'RESIDUAL WARD 2 - SUB AREA 2K'}
# {'COMM_CODE': '03D', 'COMM_NAME': 'RESIDUAL WARD 3 - SUB AREA 3D'}
# {'COMM_CODE': '03S', 'COMM_NAME': 'RESIDUAL WARD 3 - SUB AREA 3S'}
# {'COMM_CODE': '03W', 'COMM_NAME': 'RESIDUAL WARD 3 - SUB AREA 3W'}
# {'COMM_CODE': '05B', 'COMM_NAME': 'RESIDUAL WARD 5 - SUB AREA 5B'}
# {'COMM_CODE': '05C', 'COMM_NAME': 'RESIDUAL WARD 5 - SUB AREA 5C'}
# {'COMM_CODE': '05E', 'COMM_NAME': 'RESIDUAL WARD 5 - SUB AREA 5E'}
# {'COMM_CODE': '06A', 'COMM_NAME': 'RESIDUAL WARD 6 - SUB AREA 6A'}
# {'COMM_CODE': '09K', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9K'}
# {'COMM_CODE': '09N', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9N'}
# {'COMM_CODE': '09P', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9P'}
# {'COMM_CODE': '09Q', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9Q'}
# {'COMM_CODE': 'RIC', 'COMM_NAME': 'RICHMOND'}
# {'COMM_CODE': 'RID', 'COMM_NAME': 'RIDEAU PARK'}
# {'COMM_CODE': 'RIV', 'COMM_NAME': 'RIVERBEND'}
# {'COMM_CODE': 'ROC', 'COMM_NAME': 'ROCKY RIDGE'}
# {'COMM_CODE': 'RDL', 'COMM_NAME': 'ROSEDALE'}
# {'COMM_CODE': 'RMT', 'COMM_NAME': 'ROSEMONT'}
# {'COMM_CODE': 'RCK', 'COMM_NAME': 'ROSSCARROCK'}
# {'COMM_CODE': 'ROX', 'COMM_NAME': 'ROXBORO'}
# {'COMM_CODE': 'ROY', 'COMM_NAME': 'ROYAL OAK'}
# {'COMM_CODE': 'RUN', 'COMM_NAME': 'RUNDLE'}
# {'COMM_CODE': 'RUT', 'COMM_NAME': 'RUTLAND PARK'}
# {'COMM_CODE': 'SAD', 'COMM_NAME': 'SADDLE RIDGE'}
# {'COMM_CODE': 'SRI', 'COMM_NAME': 'SADDLE RIDGE INDUSTRIAL'}
# {'COMM_CODE': 'SGH', 'COMM_NAME': 'SAGE HILL'}
# {'COMM_CODE': 'SAN', 'COMM_NAME': 'SANDSTONE VALLEY'}
# {'COMM_CODE': 'SCA', 'COMM_NAME': 'SCARBORO'}
# {'COMM_CODE': 'SSW', 'COMM_NAME': 'SCARBORO/SUNALTA WEST'}
# {'COMM_CODE': 'SCE', 'COMM_NAME': 'SCENIC ACRES'}
# {'COMM_CODE': 'SET', 'COMM_NAME': 'SETON'}
# {'COMM_CODE': 'SHG', 'COMM_NAME': 'SHAGANAPPI'}
# {'COMM_CODE': 'SHS', 'COMM_NAME': 'SHAWNEE SLOPES'}
# {'COMM_CODE': 'SHN', 'COMM_NAME': 'SHAWNESSY'}
# {'COMM_CODE': 'SHI', 'COMM_NAME': 'SHEPARD INDUSTRIAL'}
# {'COMM_CODE': 'SHW', 'COMM_NAME': 'SHERWOOD'}
# {'COMM_CODE': 'SIG', 'COMM_NAME': 'SIGNAL HILL'}
# {'COMM_CODE': 'SIL', 'COMM_NAME': 'SILVER SPRINGS'}
# {'COMM_CODE': 'SVO', 'COMM_NAME': 'SILVERADO'}
# {'COMM_CODE': 'SKR', 'COMM_NAME': 'SKYVIEW RANCH'}
# {'COMM_CODE': 'SOM', 'COMM_NAME': 'SOMERSET'}
# {'COMM_CODE': 'SOC', 'COMM_NAME': 'SOUTH CALGARY'}
# {'COMM_CODE': 'SOV', 'COMM_NAME': 'SOUTHVIEW'}
# {'COMM_CODE': 'SOW', 'COMM_NAME': 'SOUTHWOOD'}
# {'COMM_CODE': 'SPH', 'COMM_NAME': 'SPRINGBANK HILL'}
# {'COMM_CODE': 'SPR', 'COMM_NAME': 'SPRUCE CLIFF'}
# {'COMM_CODE': 'STA', 'COMM_NAME': 'ST. ANDREWS HEIGHTS'}
# {'COMM_CODE': 'ST4', 'COMM_NAME': 'STONEY 4'}
# {'COMM_CODE': 'STR', 'COMM_NAME': 'STRATHCONA PARK'}
# {'COMM_CODE': 'SNA', 'COMM_NAME': 'SUNALTA'}
# {'COMM_CODE': 'SDC', 'COMM_NAME': 'SUNDANCE'}
# {'COMM_CODE': 'SSD', 'COMM_NAME': 'SUNNYSIDE'}
# {'COMM_CODE': 'TAR', 'COMM_NAME': 'TARADALE'}
# {'COMM_CODE': 'TEM', 'COMM_NAME': 'TEMPLE'}
# {'COMM_CODE': 'THO', 'COMM_NAME': 'THORNCLIFFE'}
# {'COMM_CODE': 'TUS', 'COMM_NAME': 'TUSCANY'}
# {'COMM_CODE': 'TUX', 'COMM_NAME': 'TUXEDO PARK'}
# {'COMM_CODE': 'UND', 'COMM_NAME': 'UNIVERSITY DISTRICT'}
# {'COMM_CODE': 'UNI', 'COMM_NAME': 'UNIVERSITY HEIGHTS'}
# {'COMM_CODE': 'UOC', 'COMM_NAME': 'UNIVERSITY OF CALGARY'}
# {'COMM_CODE': 'UMR', 'COMM_NAME': 'UPPER MOUNT ROYAL'}
# {'COMM_CODE': 'VAL', 'COMM_NAME': 'VALLEY RIDGE'}
# {'COMM_CODE': 'VAF', 'COMM_NAME': 'VALLEYFIELD'}
# {'COMM_CODE': 'VAR', 'COMM_NAME': 'VARSITY'}
# {'COMM_CODE': 'VIS', 'COMM_NAME': 'VISTA HEIGHTS'}
# {'COMM_CODE': 'WAL', 'COMM_NAME': 'WALDEN'}
# {'COMM_CODE': 'WHL', 'COMM_NAME': 'WEST HILLHURST'}
# {'COMM_CODE': 'WSP', 'COMM_NAME': 'WEST SPRINGS'}
# {'COMM_CODE': 'WGT', 'COMM_NAME': 'WESTGATE'}
# {'COMM_CODE': 'WHI', 'COMM_NAME': 'WHITEHORN'}
# {'COMM_CODE': 'WLD', 'COMM_NAME': 'WILDWOOD'}
# {'COMM_CODE': 'WIL', 'COMM_NAME': 'WILLOW PARK'}
# {'COMM_CODE': 'WND', 'COMM_NAME': 'WINDSOR PARK'}
# {'COMM_CODE': 'WIN', 'COMM_NAME': 'WINSTON HEIGHTS/MOUNTVIEW'}
# {'COMM_CODE': 'WBN', 'COMM_NAME': 'WOODBINE'}
# {'COMM_CODE': 'WOO', 'COMM_NAME': 'WOODLANDS'}
# {'COMM_CODE': 'YKV', 'COMM_NAME': 'YORKVILLE'}
# True

# %% [markdown]
# Community codes is the column we are using to merge our databases together. So it is good to know which Community codes are present for each of our databases to see how they properly align. On top of that, gathering this info is useful for our end project since there are Community codes/names that we can discard/ignore because we are not going to be using them. For instance there are community names that are wards (eg. "Residual Ward 1") or even community names that are extremely specific to the point that they would not normally be considered a community of calgary (For instance, there is a listed community in the list that is called Queens Park Village. When you search up this community you find out that it really isnt a community but instead is a graveyard. No idea why it is listed as well so this is one instance where we can disregard this name).

# %% [markdown]
# ## Query 2

# %%
#Get the maximum and minimum property assessment values per community

read_cursor = myconnection.cursor(buffered=True, dictionary=True)

query_string = ("SELECT max(ASSESSED_VALUE), min(ASSESSED_VALUE), COMM_CODE, COMM_NAME FROM property_data GROUP BY COMM_NAME ORDER BY COMM_NAME ASC;")

read_cursor.execute(query_string)

for (prop_value) in read_cursor:
    print(prop_value)
    
read_cursor.close()
# Out:
# {'max(ASSESSED_VALUE)': 1850000, 'min(ASSESSED_VALUE)': 170000, 'COMM_CODE': 'ABB', 'COMM_NAME': 'ABBEYDALE'}
# {'max(ASSESSED_VALUE)': 50920000, 'min(ASSESSED_VALUE)': 108500, 'COMM_CODE': 'ACA', 'COMM_NAME': 'ACADIA'}
# {'max(ASSESSED_VALUE)': 25000000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'ALB', 'COMM_NAME': 'ALBERT PARK/RADISSON HEIGHTS'}
# {'max(ASSESSED_VALUE)': 3980000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'ALT', 'COMM_NAME': 'ALTADORE'}
# {'max(ASSESSED_VALUE)': 179000, 'min(ASSESSED_VALUE)': 179000, 'COMM_CODE': 'AYB', 'COMM_NAME': 'ALYTH/BONNYBROOK'}
# {'max(ASSESSED_VALUE)': 27410000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'APP', 'COMM_NAME': 'APPLEWOOD PARK'}
# {'max(ASSESSED_VALUE)': 2020000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'ARB', 'COMM_NAME': 'ARBOUR LAKE'}
# {'max(ASSESSED_VALUE)': 28900000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'ASP', 'COMM_NAME': 'ASPEN WOODS'}
# {'max(ASSESSED_VALUE)': 49730000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'AUB', 'COMM_NAME': 'AUBURN BAY'}
# {'max(ASSESSED_VALUE)': 15070000, 'min(ASSESSED_VALUE)': 123500, 'COMM_CODE': 'BNF', 'COMM_NAME': 'BANFF TRAIL'}
# {'max(ASSESSED_VALUE)': 6680000, 'min(ASSESSED_VALUE)': 14500, 'COMM_CODE': 'BNK', 'COMM_NAME': 'BANKVIEW'}
# {'max(ASSESSED_VALUE)': 3140000, 'min(ASSESSED_VALUE)': 586000, 'COMM_CODE': 'BYV', 'COMM_NAME': 'BAYVIEW'}
# {'max(ASSESSED_VALUE)': 7050000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'BED', 'COMM_NAME': 'BEDDINGTON HEIGHTS'}
# {'max(ASSESSED_VALUE)': 5540000, 'min(ASSESSED_VALUE)': 620500, 'COMM_CODE': 'BEL', 'COMM_NAME': 'BEL-AIRE'}
# {'max(ASSESSED_VALUE)': 22900000, 'min(ASSESSED_VALUE)': 66500, 'COMM_CODE': 'BLM', 'COMM_NAME': 'BELMONT'}
# {'max(ASSESSED_VALUE)': 100300000, 'min(ASSESSED_VALUE)': 3150, 'COMM_CODE': 'BLN', 'COMM_NAME': 'BELTLINE'}
# {'max(ASSESSED_VALUE)': 2080000, 'min(ASSESSED_VALUE)': 554500, 'COMM_CODE': 'BVD', 'COMM_NAME': 'BELVEDERE'}
# {'max(ASSESSED_VALUE)': 658000, 'min(ASSESSED_VALUE)': 346000, 'COMM_CODE': 'BDO', 'COMM_NAME': 'BONAVISTA DOWNS'}
# {'max(ASSESSED_VALUE)': 15390000, 'min(ASSESSED_VALUE)': 6670, 'COMM_CODE': 'BOW', 'COMM_NAME': 'BOWNESS'}
# {'max(ASSESSED_VALUE)': 586500, 'min(ASSESSED_VALUE)': 132500, 'COMM_CODE': 'BRA', 'COMM_NAME': 'BRAESIDE'}
# {'max(ASSESSED_VALUE)': 9610000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'BRE', 'COMM_NAME': 'BRENTWOOD'}
# {'max(ASSESSED_VALUE)': 26350000, 'min(ASSESSED_VALUE)': 22000, 'COMM_CODE': 'BRD', 'COMM_NAME': 'BRIDGELAND/RIVERSIDE'}
# {'max(ASSESSED_VALUE)': 860000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'BRI', 'COMM_NAME': 'BRIDLEWOOD'}
# {'max(ASSESSED_VALUE)': 5420000, 'min(ASSESSED_VALUE)': 165500, 'COMM_CODE': 'BRT', 'COMM_NAME': 'BRITANNIA'}
# {'max(ASSESSED_VALUE)': 2030000, 'min(ASSESSED_VALUE)': 227500, 'COMM_CODE': 'CAM', 'COMM_NAME': 'CAMBRIAN HEIGHTS'}
# {'max(ASSESSED_VALUE)': 2660000, 'min(ASSESSED_VALUE)': 2550, 'COMM_CODE': 'CAN', 'COMM_NAME': 'CANYON MEADOWS'}
# {'max(ASSESSED_VALUE)': 2920000, 'min(ASSESSED_VALUE)': 0, 'COMM_CODE': 'CAP', 'COMM_NAME': 'CAPITOL HILL'}
# {'max(ASSESSED_VALUE)': 13150000, 'min(ASSESSED_VALUE)': 67500, 'COMM_CODE': 'CAR', 'COMM_NAME': 'CARRINGTON'}
# {'max(ASSESSED_VALUE)': 599000, 'min(ASSESSED_VALUE)': 213000, 'COMM_CODE': 'CAS', 'COMM_NAME': 'CASTLERIDGE'}
# {'max(ASSESSED_VALUE)': 19790000, 'min(ASSESSED_VALUE)': 191500, 'COMM_CODE': 'CED', 'COMM_NAME': 'CEDARBRAE'}
# {'max(ASSESSED_VALUE)': 2020000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'CHA', 'COMM_NAME': 'CHAPARRAL'}
# {'max(ASSESSED_VALUE)': 1880000, 'min(ASSESSED_VALUE)': 390500, 'COMM_CODE': 'CHW', 'COMM_NAME': 'CHARLESWOOD'}
# {'max(ASSESSED_VALUE)': 18580000, 'min(ASSESSED_VALUE)': 3150, 'COMM_CODE': 'CHN', 'COMM_NAME': 'CHINATOWN'}
# {'max(ASSESSED_VALUE)': 1240000, 'min(ASSESSED_VALUE)': 140500, 'COMM_CODE': 'CHK', 'COMM_NAME': 'CHINOOK PARK'}
# {'max(ASSESSED_VALUE)': 1290000, 'min(ASSESSED_VALUE)': 301500, 'COMM_CODE': 'CHR', 'COMM_NAME': 'CHRISTIE PARK'}
# {'max(ASSESSED_VALUE)': 1050000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'CIT', 'COMM_NAME': 'CITADEL'}
# {'max(ASSESSED_VALUE)': 23030000, 'min(ASSESSED_VALUE)': 8000, 'COMM_CODE': 'CSC', 'COMM_NAME': 'CITYSCAPE'}
# {'max(ASSESSED_VALUE)': 8440000, 'min(ASSESSED_VALUE)': 22000, 'COMM_CODE': 'CLI', 'COMM_NAME': 'CLIFF BUNGALOW'}
# {'max(ASSESSED_VALUE)': 3600000, 'min(ASSESSED_VALUE)': 36000, 'COMM_CODE': 'COA', 'COMM_NAME': 'COACH HILL'}
# {'max(ASSESSED_VALUE)': 2770000, 'min(ASSESSED_VALUE)': 137500, 'COMM_CODE': 'COL', 'COMM_NAME': 'COLLINGWOOD'}
# {'max(ASSESSED_VALUE)': 12660000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'CPF', 'COMM_NAME': 'COPPERFIELD'}
# {'max(ASSESSED_VALUE)': 1040000, 'min(ASSESSED_VALUE)': 251500, 'COMM_CODE': 'COR', 'COMM_NAME': 'CORAL SPRINGS'}
# {'max(ASSESSED_VALUE)': 36200000, 'min(ASSESSED_VALUE)': 1830, 'COMM_CODE': 'CNS', 'COMM_NAME': 'CORNERSTONE'}
# {'max(ASSESSED_VALUE)': 3490000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'CGR', 'COMM_NAME': 'COUGAR RIDGE'}
# {'max(ASSESSED_VALUE)': 910500, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'COU', 'COMM_NAME': 'COUNTRY HILLS'}
# {'max(ASSESSED_VALUE)': 12960000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'CHV', 'COMM_NAME': 'COUNTRY HILLS VILLAGE'}
# {'max(ASSESSED_VALUE)': 640500, 'min(ASSESSED_VALUE)': 243500, 'COMM_CODE': 'COV', 'COMM_NAME': 'COVENTRY HILLS'}
# {'max(ASSESSED_VALUE)': 9480000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'CRA', 'COMM_NAME': 'CRANSTON'}
# {'max(ASSESSED_VALUE)': 9060000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'CRE', 'COMM_NAME': 'CRESCENT HEIGHTS'}
# {'max(ASSESSED_VALUE)': 10990000, 'min(ASSESSED_VALUE)': 2850, 'COMM_CODE': 'CRM', 'COMM_NAME': 'CRESTMONT'}
# {'max(ASSESSED_VALUE)': 47710000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'CUR', 'COMM_NAME': 'CURRIE BARRACKS'}
# {'max(ASSESSED_VALUE)': 15890000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'DAL', 'COMM_NAME': 'DALHOUSIE'}
# {'max(ASSESSED_VALUE)': 8120000, 'min(ASSESSED_VALUE)': 205000, 'COMM_CODE': 'DRG', 'COMM_NAME': 'DEER RIDGE'}
# {'max(ASSESSED_VALUE)': 763500, 'min(ASSESSED_VALUE)': 122500, 'COMM_CODE': 'DRN', 'COMM_NAME': 'DEER RUN'}
# {'max(ASSESSED_VALUE)': 934500, 'min(ASSESSED_VALUE)': 459000, 'COMM_CODE': 'DIA', 'COMM_NAME': 'DIAMOND COVE'}
# {'max(ASSESSED_VALUE)': 1760000, 'min(ASSESSED_VALUE)': 22000, 'COMM_CODE': 'DIS', 'COMM_NAME': 'DISCOVERY RIDGE'}
# {'max(ASSESSED_VALUE)': 40220000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'DDG', 'COMM_NAME': 'DOUGLASDALE/GLEN'}
# {'max(ASSESSED_VALUE)': 49030000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'DOV', 'COMM_NAME': 'DOVER'}
# {'max(ASSESSED_VALUE)': 93490000, 'min(ASSESSED_VALUE)': 3150, 'COMM_CODE': 'DNC', 'COMM_NAME': 'DOWNTOWN COMMERCIAL CORE'}
# {'max(ASSESSED_VALUE)': 60220000, 'min(ASSESSED_VALUE)': 34000, 'COMM_CODE': 'DNE', 'COMM_NAME': 'DOWNTOWN EAST VILLAGE'}
# {'max(ASSESSED_VALUE)': 5000000, 'min(ASSESSED_VALUE)': 34000, 'COMM_CODE': 'DNW', 'COMM_NAME': 'DOWNTOWN WEST END'}
# {'max(ASSESSED_VALUE)': 4100000, 'min(ASSESSED_VALUE)': 782500, 'COMM_CODE': 'EAG', 'COMM_NAME': 'EAGLE RIDGE'}
# {'max(ASSESSED_VALUE)': 72140000, 'min(ASSESSED_VALUE)': 3150, 'COMM_CODE': 'EAU', 'COMM_NAME': 'EAU CLAIRE'}
# {'max(ASSESSED_VALUE)': 1710000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'EDG', 'COMM_NAME': 'EDGEMONT'}
# {'max(ASSESSED_VALUE)': 5580000, 'min(ASSESSED_VALUE)': 6500, 'COMM_CODE': 'EPK', 'COMM_NAME': 'ELBOW PARK'}
# {'max(ASSESSED_VALUE)': 3140000, 'min(ASSESSED_VALUE)': 110000, 'COMM_CODE': 'EYA', 'COMM_NAME': 'ELBOYA'}
# {'max(ASSESSED_VALUE)': 12920000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'ERI', 'COMM_NAME': 'ERIN WOODS'}
# {'max(ASSESSED_VALUE)': 3500000, 'min(ASSESSED_VALUE)': 22000, 'COMM_CODE': 'ERL', 'COMM_NAME': 'ERLTON'}
# {'max(ASSESSED_VALUE)': 3390000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'EVN', 'COMM_NAME': 'EVANSTON'}
# {'max(ASSESSED_VALUE)': 24090000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'EVE', 'COMM_NAME': 'EVERGREEN'}
# {'max(ASSESSED_VALUE)': 23230000, 'min(ASSESSED_VALUE)': 352500, 'COMM_CODE': 'FAI', 'COMM_NAME': 'FAIRVIEW'}
# {'max(ASSESSED_VALUE)': 28310000, 'min(ASSESSED_VALUE)': 140500, 'COMM_CODE': 'FAL', 'COMM_NAME': 'FALCONRIDGE'}
# {'max(ASSESSED_VALUE)': 4700000, 'min(ASSESSED_VALUE)': 136000, 'COMM_CODE': 'FHT', 'COMM_NAME': 'FOREST HEIGHTS'}
# {'max(ASSESSED_VALUE)': 33380000, 'min(ASSESSED_VALUE)': 0, 'COMM_CODE': 'FLN', 'COMM_NAME': 'FOREST LAWN'}
# {'max(ASSESSED_VALUE)': 689500, 'min(ASSESSED_VALUE)': 689500, 'COMM_CODE': 'FRA', 'COMM_NAME': 'FRANKLIN'}
# {'max(ASSESSED_VALUE)': 38310000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'GAG', 'COMM_NAME': 'GARRISON GREEN'}
# {'max(ASSESSED_VALUE)': 1820000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'GAW', 'COMM_NAME': 'GARRISON WOODS'}
# {'max(ASSESSED_VALUE)': 8010000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'GLA', 'COMM_NAME': 'GLAMORGAN'}
# {'max(ASSESSED_VALUE)': 31640000, 'min(ASSESSED_VALUE)': 137000, 'COMM_CODE': 'GBK', 'COMM_NAME': 'GLENBROOK'}
# {'max(ASSESSED_VALUE)': 11110000, 'min(ASSESSED_VALUE)': 306000, 'COMM_CODE': 'GDL', 'COMM_NAME': 'GLENDALE'}
# {'max(ASSESSED_VALUE)': 892000, 'min(ASSESSED_VALUE)': 892000, 'COMM_CODE': 'GPK', 'COMM_NAME': 'GLENMORE PARK'}
# {'max(ASSESSED_VALUE)': 6460000, 'min(ASSESSED_VALUE)': 109500, 'COMM_CODE': 'GRV', 'COMM_NAME': 'GREENVIEW'}
# {'max(ASSESSED_VALUE)': 19650000, 'min(ASSESSED_VALUE)': 280500, 'COMM_CODE': 'GRI', 'COMM_NAME': 'GREENVIEW INDUSTRIAL PARK'}
# {'max(ASSESSED_VALUE)': 32490000, 'min(ASSESSED_VALUE)': 256000, 'COMM_CODE': 'GRE', 'COMM_NAME': 'GREENWOOD/GREENBRIAR'}
# {'max(ASSESSED_VALUE)': 1470000, 'min(ASSESSED_VALUE)': 330500, 'COMM_CODE': 'HAM', 'COMM_NAME': 'HAMPTONS'}
# {'max(ASSESSED_VALUE)': 5650000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'HAR', 'COMM_NAME': 'HARVEST HILLS'}
# {'max(ASSESSED_VALUE)': 1270000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'HAW', 'COMM_NAME': 'HAWKWOOD'}
# {'max(ASSESSED_VALUE)': 1030000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'HAY', 'COMM_NAME': 'HAYSBORO'}
# {'max(ASSESSED_VALUE)': 1070000, 'min(ASSESSED_VALUE)': 196000, 'COMM_CODE': 'HID', 'COMM_NAME': 'HIDDEN VALLEY'}
# {'max(ASSESSED_VALUE)': 13670000, 'min(ASSESSED_VALUE)': 78500, 'COMM_CODE': 'HPK', 'COMM_NAME': 'HIGHLAND PARK'}
# {'max(ASSESSED_VALUE)': 1060000, 'min(ASSESSED_VALUE)': 138000, 'COMM_CODE': 'HIW', 'COMM_NAME': 'HIGHWOOD'}
# {'max(ASSESSED_VALUE)': 13680000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'HIL', 'COMM_NAME': 'HILLHURST'}
# {'max(ASSESSED_VALUE)': 690500, 'min(ASSESSED_VALUE)': 484500, 'COMM_CODE': 'HKS', 'COMM_NAME': 'HOTCHKISS'}
# {'max(ASSESSED_VALUE)': 41480000, 'min(ASSESSED_VALUE)': 4340, 'COMM_CODE': 'HOU', 'COMM_NAME': 'HOUNSFIELD HEIGHTS/BRIAR HILL'}
# {'max(ASSESSED_VALUE)': 22690000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'HUN', 'COMM_NAME': 'HUNTINGTON HILLS'}
# {'max(ASSESSED_VALUE)': 7380000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'ING', 'COMM_NAME': 'INGLEWOOD'}
# {'max(ASSESSED_VALUE)': 3730000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'KEL', 'COMM_NAME': 'KELVIN GROVE'}
# {'max(ASSESSED_VALUE)': 7920000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'KIL', 'COMM_NAME': 'KILLARNEY/GLENGARRY'}
# {'max(ASSESSED_VALUE)': 27400000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'KCA', 'COMM_NAME': 'KINCORA'}
# {'max(ASSESSED_VALUE)': 21530000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'KIN', 'COMM_NAME': 'KINGSLAND'}
# {'max(ASSESSED_VALUE)': 3730000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'LKB', 'COMM_NAME': 'LAKE BONAVISTA'}
# {'max(ASSESSED_VALUE)': 17530000, 'min(ASSESSED_VALUE)': 296000, 'COMM_CODE': 'LKV', 'COMM_NAME': 'LAKEVIEW'}
# {'max(ASSESSED_VALUE)': 20940000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'LEG', 'COMM_NAME': 'LEGACY'}
# {'max(ASSESSED_VALUE)': 5770000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'LPK', 'COMM_NAME': 'LINCOLN PARK'}
# {'max(ASSESSED_VALUE)': 12030000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'LIV', 'COMM_NAME': 'LIVINGSTON'}
# {'max(ASSESSED_VALUE)': 9040000, 'min(ASSESSED_VALUE)': 3150, 'COMM_CODE': 'LMR', 'COMM_NAME': 'LOWER MOUNT ROYAL'}
# {'max(ASSESSED_VALUE)': 753000, 'min(ASSESSED_VALUE)': 230000, 'COMM_CODE': 'MAC', 'COMM_NAME': 'MACEWAN'}
# {'max(ASSESSED_VALUE)': 23360000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'MAH', 'COMM_NAME': 'MAHOGANY'}
# {'max(ASSESSED_VALUE)': 23670000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'MAN', 'COMM_NAME': 'MANCHESTER'}
# {'max(ASSESSED_VALUE)': 884500, 'min(ASSESSED_VALUE)': 408000, 'COMM_CODE': 'MPL', 'COMM_NAME': 'MAPLE RIDGE'}
# {'max(ASSESSED_VALUE)': 526000, 'min(ASSESSED_VALUE)': 175000, 'COMM_CODE': 'MRL', 'COMM_NAME': 'MARLBOROUGH'}
# {'max(ASSESSED_VALUE)': 508000, 'min(ASSESSED_VALUE)': 5000, 'COMM_CODE': 'MPK', 'COMM_NAME': 'MARLBOROUGH PARK'}
# {'max(ASSESSED_VALUE)': 627500, 'min(ASSESSED_VALUE)': 128000, 'COMM_CODE': 'MRT', 'COMM_NAME': 'MARTINDALE'}
# {'max(ASSESSED_VALUE)': 2500000, 'min(ASSESSED_VALUE)': 605000, 'COMM_CODE': 'MAF', 'COMM_NAME': 'MAYFAIR'}
# {'max(ASSESSED_VALUE)': 12490000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'MAL', 'COMM_NAME': 'MAYLAND HEIGHTS'}
# {'max(ASSESSED_VALUE)': 10620000, 'min(ASSESSED_VALUE)': 196500, 'COMM_CODE': 'MCK', 'COMM_NAME': 'MCKENZIE LAKE'}
# {'max(ASSESSED_VALUE)': 15870000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'MCT', 'COMM_NAME': 'MCKENZIE TOWNE'}
# {'max(ASSESSED_VALUE)': 2010000, 'min(ASSESSED_VALUE)': 422500, 'COMM_CODE': 'MEA', 'COMM_NAME': 'MEADOWLARK PARK'}
# {'max(ASSESSED_VALUE)': 6680000, 'min(ASSESSED_VALUE)': 4390000, 'COMM_CODE': 'MDH', 'COMM_NAME': 'MEDICINE HILL'}
# {'max(ASSESSED_VALUE)': 33270000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'MID', 'COMM_NAME': 'MIDNAPORE'}
# {'max(ASSESSED_VALUE)': 596500, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'MLR', 'COMM_NAME': 'MILLRISE'}
# {'max(ASSESSED_VALUE)': 50860000, 'min(ASSESSED_VALUE)': 3150, 'COMM_CODE': 'MIS', 'COMM_NAME': 'MISSION'}
# {'max(ASSESSED_VALUE)': 19450000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'MOR', 'COMM_NAME': 'MONTEREY PARK'}
# {'max(ASSESSED_VALUE)': 1990000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'MON', 'COMM_NAME': 'MONTGOMERY'}
# {'max(ASSESSED_VALUE)': 2070000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'MOP', 'COMM_NAME': 'MOUNT PLEASANT'}
# {'max(ASSESSED_VALUE)': 722000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'NEB', 'COMM_NAME': 'NEW BRIGHTON'}
# {'max(ASSESSED_VALUE)': 14320000, 'min(ASSESSED_VALUE)': 53000, 'COMM_CODE': 'NOL', 'COMM_NAME': 'NOLAN HILL'}
# {'max(ASSESSED_VALUE)': 3700000, 'min(ASSESSED_VALUE)': 148500, 'COMM_CODE': 'NGM', 'COMM_NAME': 'NORTH GLENMORE PARK'}
# {'max(ASSESSED_VALUE)': 2880000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'NHV', 'COMM_NAME': 'NORTH HAVEN'}
# {'max(ASSESSED_VALUE)': 917000, 'min(ASSESSED_VALUE)': 372500, 'COMM_CODE': 'NHU', 'COMM_NAME': 'NORTH HAVEN UPPER'}
# {'max(ASSESSED_VALUE)': 4890000, 'min(ASSESSED_VALUE)': 153500, 'COMM_CODE': 'OAK', 'COMM_NAME': 'OAKRIDGE'}
# {'max(ASSESSED_VALUE)': 41250000, 'min(ASSESSED_VALUE)': 40000, 'COMM_CODE': 'OGD', 'COMM_NAME': 'OGDEN'}
# {'max(ASSESSED_VALUE)': 28820000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'PAL', 'COMM_NAME': 'PALLISER'}
# {'max(ASSESSED_VALUE)': 1980000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'PAN', 'COMM_NAME': 'PANORAMA HILLS'}
# {'max(ASSESSED_VALUE)': 20930000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'PKD', 'COMM_NAME': 'PARKDALE'}
# {'max(ASSESSED_VALUE)': 6540000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'PKH', 'COMM_NAME': 'PARKHILL/STANLEY PARK'}
# {'max(ASSESSED_VALUE)': 1170000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'PKL', 'COMM_NAME': 'PARKLAND'}
# {'max(ASSESSED_VALUE)': 32600000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'PAT', 'COMM_NAME': 'PATTERSON'}
# {'max(ASSESSED_VALUE)': 4880000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'PEN', 'COMM_NAME': 'PENBROOKE MEADOWS'}
# {'max(ASSESSED_VALUE)': 2600000, 'min(ASSESSED_VALUE)': 629000, 'COMM_CODE': 'PCK', 'COMM_NAME': 'PINE CREEK'}
# {'max(ASSESSED_VALUE)': 35040000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'PIN', 'COMM_NAME': 'PINERIDGE'}
# {'max(ASSESSED_VALUE)': 796500, 'min(ASSESSED_VALUE)': 153500, 'COMM_CODE': 'POI', 'COMM_NAME': 'POINT MCKAY'}
# {'max(ASSESSED_VALUE)': 18490000, 'min(ASSESSED_VALUE)': 579000, 'COMM_CODE': 'PUM', 'COMM_NAME': 'PUMP HILL'}
# {'max(ASSESSED_VALUE)': 29060000, 'min(ASSESSED_VALUE)': 29060000, 'COMM_CODE': 'QPK', 'COMM_NAME': 'QUEENS PARK VILLAGE'}
# {'max(ASSESSED_VALUE)': 9090000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'QLD', 'COMM_NAME': 'QUEENSLAND'}
# {'max(ASSESSED_VALUE)': 6020000, 'min(ASSESSED_VALUE)': 287500, 'COMM_CODE': 'RAM', 'COMM_NAME': 'RAMSAY'}
# {'max(ASSESSED_VALUE)': 9410000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'RAN', 'COMM_NAME': 'RANCHLANDS'}
# {'max(ASSESSED_VALUE)': 996000, 'min(ASSESSED_VALUE)': 996000, 'COMM_CODE': 'RVW', 'COMM_NAME': 'RANGEVIEW'}
# {'max(ASSESSED_VALUE)': 14190000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'RED', 'COMM_NAME': 'RED CARPET/MOUNTVIEW MOBILE PARK'}
# {'max(ASSESSED_VALUE)': 11800000, 'min(ASSESSED_VALUE)': 54000, 'COMM_CODE': 'RSN', 'COMM_NAME': 'REDSTONE'}
# {'max(ASSESSED_VALUE)': 3970000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'REN', 'COMM_NAME': 'RENFREW'}
# {'max(ASSESSED_VALUE)': 2480000, 'min(ASSESSED_VALUE)': 570500, 'COMM_CODE': '01C', 'COMM_NAME': 'RESIDUAL WARD 1 - CALGARY WEST'}
# {'max(ASSESSED_VALUE)': 1640000, 'min(ASSESSED_VALUE)': 1640000, 'COMM_CODE': '01D', 'COMM_NAME': 'RESIDUAL WARD 1 - CANADA OLYMPIC PARK'}
# {'max(ASSESSED_VALUE)': 1800000, 'min(ASSESSED_VALUE)': 750000, 'COMM_CODE': '01F', 'COMM_NAME': 'RESIDUAL WARD 1 - SUB AREA 1F'}
# {'max(ASSESSED_VALUE)': 1880000, 'min(ASSESSED_VALUE)': 858500, 'COMM_CODE': '01H', 'COMM_NAME': 'RESIDUAL WARD 1 - SUB AREA 1H'}
# {'max(ASSESSED_VALUE)': 1510000, 'min(ASSESSED_VALUE)': 400500, 'COMM_CODE': '10A', 'COMM_NAME': 'RESIDUAL WARD 10 - SUB AREA 10A'}
# {'max(ASSESSED_VALUE)': 707000, 'min(ASSESSED_VALUE)': 707000, 'COMM_CODE': '10B', 'COMM_NAME': 'RESIDUAL WARD 10 - SUB AREA 10B'}
# {'max(ASSESSED_VALUE)': 1560000, 'min(ASSESSED_VALUE)': 210, 'COMM_CODE': '10C', 'COMM_NAME': 'RESIDUAL WARD 10 - SUB AREA 10C'}
# {'max(ASSESSED_VALUE)': 537500, 'min(ASSESSED_VALUE)': 118500, 'COMM_CODE': '12A', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12A'}
# {'max(ASSESSED_VALUE)': 1200000, 'min(ASSESSED_VALUE)': 874000, 'COMM_CODE': '12B', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12B'}
# {'max(ASSESSED_VALUE)': 2500000, 'min(ASSESSED_VALUE)': 660000, 'COMM_CODE': '12C', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12C'}
# {'max(ASSESSED_VALUE)': 460000, 'min(ASSESSED_VALUE)': 460000, 'COMM_CODE': '12I', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12I'}
# {'max(ASSESSED_VALUE)': 2170000, 'min(ASSESSED_VALUE)': 724000, 'COMM_CODE': '12J', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12J'}
# {'max(ASSESSED_VALUE)': 860500, 'min(ASSESSED_VALUE)': 329500, 'COMM_CODE': '12L', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12L'}
# {'max(ASSESSED_VALUE)': 751500, 'min(ASSESSED_VALUE)': 751500, 'COMM_CODE': '13C', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13C'}
# {'max(ASSESSED_VALUE)': 808500, 'min(ASSESSED_VALUE)': 516000, 'COMM_CODE': '13D', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13D'}
# {'max(ASSESSED_VALUE)': 745001, 'min(ASSESSED_VALUE)': 745001, 'COMM_CODE': '13E', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13E'}
# {'max(ASSESSED_VALUE)': 2310000, 'min(ASSESSED_VALUE)': 685500, 'COMM_CODE': '13F', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13F'}
# {'max(ASSESSED_VALUE)': 900000, 'min(ASSESSED_VALUE)': 201500, 'COMM_CODE': '13G', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13G'}
# {'max(ASSESSED_VALUE)': 1830000, 'min(ASSESSED_VALUE)': 649500, 'COMM_CODE': '14V', 'COMM_NAME': 'RESIDUAL WARD 14 - SUB AREA 14V'}
# {'max(ASSESSED_VALUE)': 760000, 'min(ASSESSED_VALUE)': 381500, 'COMM_CODE': '02L', 'COMM_NAME': 'RESIDUAL WARD 2 - SUB AREA 02L'}
# {'max(ASSESSED_VALUE)': 492500, 'min(ASSESSED_VALUE)': 476501, 'COMM_CODE': '02C', 'COMM_NAME': 'RESIDUAL WARD 2 - SUB AREA 2C'}
# {'max(ASSESSED_VALUE)': 765500, 'min(ASSESSED_VALUE)': 765500, 'COMM_CODE': '02K', 'COMM_NAME': 'RESIDUAL WARD 2 - SUB AREA 2K'}
# {'max(ASSESSED_VALUE)': 438500, 'min(ASSESSED_VALUE)': 125500, 'COMM_CODE': '03D', 'COMM_NAME': 'RESIDUAL WARD 3 - SUB AREA 3D'}
# {'max(ASSESSED_VALUE)': 662000, 'min(ASSESSED_VALUE)': 662000, 'COMM_CODE': '03S', 'COMM_NAME': 'RESIDUAL WARD 3 - SUB AREA 3S'}
# {'max(ASSESSED_VALUE)': 1730000, 'min(ASSESSED_VALUE)': 403500, 'COMM_CODE': '03W', 'COMM_NAME': 'RESIDUAL WARD 3 - SUB AREA 3W'}
# {'max(ASSESSED_VALUE)': 2390000, 'min(ASSESSED_VALUE)': 618000, 'COMM_CODE': '05B', 'COMM_NAME': 'RESIDUAL WARD 5 - SUB AREA 5B'}
# {'max(ASSESSED_VALUE)': 539000, 'min(ASSESSED_VALUE)': 539000, 'COMM_CODE': '05C', 'COMM_NAME': 'RESIDUAL WARD 5 - SUB AREA 5C'}
# {'max(ASSESSED_VALUE)': 820500, 'min(ASSESSED_VALUE)': 820500, 'COMM_CODE': '05E', 'COMM_NAME': 'RESIDUAL WARD 5 - SUB AREA 5E'}
# {'max(ASSESSED_VALUE)': 1440000, 'min(ASSESSED_VALUE)': 486000, 'COMM_CODE': '06A', 'COMM_NAME': 'RESIDUAL WARD 6 - SUB AREA 6A'}
# {'max(ASSESSED_VALUE)': 467500, 'min(ASSESSED_VALUE)': 467500, 'COMM_CODE': '09K', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9K'}
# {'max(ASSESSED_VALUE)': 3240000, 'min(ASSESSED_VALUE)': 3240000, 'COMM_CODE': '09N', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9N'}
# {'max(ASSESSED_VALUE)': 810000, 'min(ASSESSED_VALUE)': 810000, 'COMM_CODE': '09P', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9P'}
# {'max(ASSESSED_VALUE)': 366500, 'min(ASSESSED_VALUE)': 366500, 'COMM_CODE': '09Q', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9Q'}
# {'max(ASSESSED_VALUE)': 3760000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'RIC', 'COMM_NAME': 'RICHMOND'}
# {'max(ASSESSED_VALUE)': 4030000, 'min(ASSESSED_VALUE)': 197000, 'COMM_CODE': 'RID', 'COMM_NAME': 'RIDEAU PARK'}
# {'max(ASSESSED_VALUE)': 694000, 'min(ASSESSED_VALUE)': 104000, 'COMM_CODE': 'RIV', 'COMM_NAME': 'RIVERBEND'}
# {'max(ASSESSED_VALUE)': 3000000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'ROC', 'COMM_NAME': 'ROCKY RIDGE'}
# {'max(ASSESSED_VALUE)': 4420000, 'min(ASSESSED_VALUE)': 196000, 'COMM_CODE': 'RDL', 'COMM_NAME': 'ROSEDALE'}
# {'max(ASSESSED_VALUE)': 2390000, 'min(ASSESSED_VALUE)': 315500, 'COMM_CODE': 'RMT', 'COMM_NAME': 'ROSEMONT'}
# {'max(ASSESSED_VALUE)': 8700000, 'min(ASSESSED_VALUE)': 22000, 'COMM_CODE': 'RCK', 'COMM_NAME': 'ROSSCARROCK'}
# {'max(ASSESSED_VALUE)': 5190000, 'min(ASSESSED_VALUE)': 281500, 'COMM_CODE': 'ROX', 'COMM_NAME': 'ROXBORO'}
# {'max(ASSESSED_VALUE)': 4730000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'ROY', 'COMM_NAME': 'ROYAL OAK'}
# {'max(ASSESSED_VALUE)': 702500, 'min(ASSESSED_VALUE)': 151500, 'COMM_CODE': 'RUN', 'COMM_NAME': 'RUNDLE'}
# {'max(ASSESSED_VALUE)': 8550000, 'min(ASSESSED_VALUE)': 223500, 'COMM_CODE': 'RUT', 'COMM_NAME': 'RUTLAND PARK'}
# {'max(ASSESSED_VALUE)': 4630000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'SAD', 'COMM_NAME': 'SADDLE RIDGE'}
# {'max(ASSESSED_VALUE)': 2270000, 'min(ASSESSED_VALUE)': 2100000, 'COMM_CODE': 'SRI', 'COMM_NAME': 'SADDLE RIDGE INDUSTRIAL'}
# {'max(ASSESSED_VALUE)': 40210000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'SGH', 'COMM_NAME': 'SAGE HILL'}
# {'max(ASSESSED_VALUE)': 684500, 'min(ASSESSED_VALUE)': 243500, 'COMM_CODE': 'SAN', 'COMM_NAME': 'SANDSTONE VALLEY'}
# {'max(ASSESSED_VALUE)': 3110000, 'min(ASSESSED_VALUE)': 362000, 'COMM_CODE': 'SCA', 'COMM_NAME': 'SCARBORO'}
# {'max(ASSESSED_VALUE)': 2680000, 'min(ASSESSED_VALUE)': 516000, 'COMM_CODE': 'SSW', 'COMM_NAME': 'SCARBORO/SUNALTA WEST'}
# {'max(ASSESSED_VALUE)': 4040000, 'min(ASSESSED_VALUE)': 265000, 'COMM_CODE': 'SCE', 'COMM_NAME': 'SCENIC ACRES'}
# {'max(ASSESSED_VALUE)': 44510000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'SET', 'COMM_NAME': 'SETON'}
# {'max(ASSESSED_VALUE)': 24130000, 'min(ASSESSED_VALUE)': 14500, 'COMM_CODE': 'SHG', 'COMM_NAME': 'SHAGANAPPI'}
# {'max(ASSESSED_VALUE)': 10070000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'SHS', 'COMM_NAME': 'SHAWNEE SLOPES'}
# {'max(ASSESSED_VALUE)': 6290000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'SHN', 'COMM_NAME': 'SHAWNESSY'}
# {'max(ASSESSED_VALUE)': 2250000, 'min(ASSESSED_VALUE)': 103000, 'COMM_CODE': 'SHI', 'COMM_NAME': 'SHEPARD INDUSTRIAL'}
# {'max(ASSESSED_VALUE)': 922500, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'SHW', 'COMM_NAME': 'SHERWOOD'}
# {'max(ASSESSED_VALUE)': 4280000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'SIG', 'COMM_NAME': 'SIGNAL HILL'}
# {'max(ASSESSED_VALUE)': 1430000, 'min(ASSESSED_VALUE)': 144000, 'COMM_CODE': 'SIL', 'COMM_NAME': 'SILVER SPRINGS'}
# {'max(ASSESSED_VALUE)': 8920000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'SVO', 'COMM_NAME': 'SILVERADO'}
# {'max(ASSESSED_VALUE)': 27150000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'SKR', 'COMM_NAME': 'SKYVIEW RANCH'}
# {'max(ASSESSED_VALUE)': 16620000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'SOM', 'COMM_NAME': 'SOMERSET'}
# {'max(ASSESSED_VALUE)': 3590000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'SOC', 'COMM_NAME': 'SOUTH CALGARY'}
# {'max(ASSESSED_VALUE)': 5040000, 'min(ASSESSED_VALUE)': 210000, 'COMM_CODE': 'SOV', 'COMM_NAME': 'SOUTHVIEW'}
# {'max(ASSESSED_VALUE)': 6230000, 'min(ASSESSED_VALUE)': 96000, 'COMM_CODE': 'SOW', 'COMM_NAME': 'SOUTHWOOD'}
# {'max(ASSESSED_VALUE)': 14570000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'SPH', 'COMM_NAME': 'SPRINGBANK HILL'}
# {'max(ASSESSED_VALUE)': 39910000, 'min(ASSESSED_VALUE)': 4030, 'COMM_CODE': 'SPR', 'COMM_NAME': 'SPRUCE CLIFF'}
# {'max(ASSESSED_VALUE)': 17270000, 'min(ASSESSED_VALUE)': 245000, 'COMM_CODE': 'STA', 'COMM_NAME': 'ST. ANDREWS HEIGHTS'}
# {'max(ASSESSED_VALUE)': 485001, 'min(ASSESSED_VALUE)': 485001, 'COMM_CODE': 'ST4', 'COMM_NAME': 'STONEY 4'}
# {'max(ASSESSED_VALUE)': 1560000, 'min(ASSESSED_VALUE)': 276000, 'COMM_CODE': 'STR', 'COMM_NAME': 'STRATHCONA PARK'}
# {'max(ASSESSED_VALUE)': 4100000, 'min(ASSESSED_VALUE)': 14500, 'COMM_CODE': 'SNA', 'COMM_NAME': 'SUNALTA'}
# {'max(ASSESSED_VALUE)': 12080000, 'min(ASSESSED_VALUE)': 275000, 'COMM_CODE': 'SDC', 'COMM_NAME': 'SUNDANCE'}
# {'max(ASSESSED_VALUE)': 6110000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'SSD', 'COMM_NAME': 'SUNNYSIDE'}
# {'max(ASSESSED_VALUE)': 1460000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'TAR', 'COMM_NAME': 'TARADALE'}
# {'max(ASSESSED_VALUE)': 692000, 'min(ASSESSED_VALUE)': 129000, 'COMM_CODE': 'TEM', 'COMM_NAME': 'TEMPLE'}
# {'max(ASSESSED_VALUE)': 15290000, 'min(ASSESSED_VALUE)': 112000, 'COMM_CODE': 'THO', 'COMM_NAME': 'THORNCLIFFE'}
# {'max(ASSESSED_VALUE)': 3770000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'TUS', 'COMM_NAME': 'TUSCANY'}
# {'max(ASSESSED_VALUE)': 2060000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'TUX', 'COMM_NAME': 'TUXEDO PARK'}
# {'max(ASSESSED_VALUE)': 46240000, 'min(ASSESSED_VALUE)': 0, 'COMM_CODE': 'UND', 'COMM_NAME': 'UNIVERSITY DISTRICT'}
# {'max(ASSESSED_VALUE)': 65590000, 'min(ASSESSED_VALUE)': 51500, 'COMM_CODE': 'UNI', 'COMM_NAME': 'UNIVERSITY HEIGHTS'}
# {'max(ASSESSED_VALUE)': 42390000, 'min(ASSESSED_VALUE)': 14520000, 'COMM_CODE': 'UOC', 'COMM_NAME': 'UNIVERSITY OF CALGARY'}
# {'max(ASSESSED_VALUE)': 19900000, 'min(ASSESSED_VALUE)': 14500, 'COMM_CODE': 'UMR', 'COMM_NAME': 'UPPER MOUNT ROYAL'}
# {'max(ASSESSED_VALUE)': 15590000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'VAL', 'COMM_NAME': 'VALLEY RIDGE'}
# {'max(ASSESSED_VALUE)': 322500, 'min(ASSESSED_VALUE)': 214000, 'COMM_CODE': 'VAF', 'COMM_NAME': 'VALLEYFIELD'}
# {'max(ASSESSED_VALUE)': 53870000, 'min(ASSESSED_VALUE)': 3050, 'COMM_CODE': 'VAR', 'COMM_NAME': 'VARSITY'}
# {'max(ASSESSED_VALUE)': 20900000, 'min(ASSESSED_VALUE)': 162500, 'COMM_CODE': 'VIS', 'COMM_NAME': 'VISTA HEIGHTS'}
# {'max(ASSESSED_VALUE)': 31720000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'WAL', 'COMM_NAME': 'WALDEN'}
# {'max(ASSESSED_VALUE)': 12320000, 'min(ASSESSED_VALUE)': 14500, 'COMM_CODE': 'WHL', 'COMM_NAME': 'WEST HILLHURST'}
# {'max(ASSESSED_VALUE)': 36810000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'WSP', 'COMM_NAME': 'WEST SPRINGS'}
# {'max(ASSESSED_VALUE)': 15030000, 'min(ASSESSED_VALUE)': 157500, 'COMM_CODE': 'WGT', 'COMM_NAME': 'WESTGATE'}
# {'max(ASSESSED_VALUE)': 608500, 'min(ASSESSED_VALUE)': 145000, 'COMM_CODE': 'WHI', 'COMM_NAME': 'WHITEHORN'}
# {'max(ASSESSED_VALUE)': 6840000, 'min(ASSESSED_VALUE)': 355000, 'COMM_CODE': 'WLD', 'COMM_NAME': 'WILDWOOD'}
# {'max(ASSESSED_VALUE)': 10750000, 'min(ASSESSED_VALUE)': 190000, 'COMM_CODE': 'WIL', 'COMM_NAME': 'WILLOW PARK'}
# {'max(ASSESSED_VALUE)': 14110000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'WND', 'COMM_NAME': 'WINDSOR PARK'}
# {'max(ASSESSED_VALUE)': 3220000, 'min(ASSESSED_VALUE)': 10000, 'COMM_CODE': 'WIN', 'COMM_NAME': 'WINSTON HEIGHTS/MOUNTVIEW'}
# {'max(ASSESSED_VALUE)': 2320000, 'min(ASSESSED_VALUE)': 224000, 'COMM_CODE': 'WBN', 'COMM_NAME': 'WOODBINE'}
# {'max(ASSESSED_VALUE)': 14620000, 'min(ASSESSED_VALUE)': 201500, 'COMM_CODE': 'WOO', 'COMM_NAME': 'WOODLANDS'}
# {'max(ASSESSED_VALUE)': 45460000, 'min(ASSESSED_VALUE)': 45460000, 'COMM_CODE': 'YKV', 'COMM_NAME': 'YORKVILLE'}
# True

# %% [markdown]
# Getting the max and min property values per community allows us to see the range of property assessment values. This lets us look and see if there are any typos for assessment values entered that we can ignore. From looking at the min and max values we decided to start using a threshold for property assessment values (greater than 100,000). We chose to do this because our data for property assessment values also included monthly rent costs which would have interfered with future queries such as when we grab an average for property assessment values. For this project we wanted to focus solely on property values (cost for buying an entire property) and not include rent since it would be tricky trying to differentiate between the two since they are together in the same column/field. So setting our threshold to 100,000 allowed us to negate any rows that used monthly/yearly rent prices and also helped us ignore any property assessment values that were set to 0 because they were not properly recorded when the data was gathered. We chose to use a threshold of 100,000 as well because realistically you would be winning the lottery for finding a property that is less than 100,000 in Calgary. This threshold value also allowed us to keep rows that would have the property assessment values for buying an apartment outright rather than renting (which we still considered the same as buying your own home).

# %% [markdown]
# ## Query 3

# %%
#Get the total property assessment count per each community above the chosen property assessment value threshold

read_cursor = myconnection.cursor(buffered=True, dictionary=True)

query_string = ("SELECT count(COMM_CODE), COMM_CODE, COMM_NAME FROM property_data WHERE ASSESSED_VALUE > 100000 GROUP BY COMM_NAME;")

read_cursor.execute(query_string)

for (prop_value) in read_cursor:
    print(prop_value)
    
read_cursor.close()
# Out:
# {'count(COMM_CODE)': 735, 'COMM_CODE': 'ABB', 'COMM_NAME': 'ABBEYDALE'}
# {'count(COMM_CODE)': 1419, 'COMM_CODE': 'ACA', 'COMM_NAME': 'ACADIA'}
# {'count(COMM_CODE)': 707, 'COMM_CODE': 'ALB', 'COMM_NAME': 'ALBERT PARK/RADISSON HEIGHTS'}
# {'count(COMM_CODE)': 1037, 'COMM_CODE': 'ALT', 'COMM_NAME': 'ALTADORE'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': 'AYB', 'COMM_NAME': 'ALYTH/BONNYBROOK'}
# {'count(COMM_CODE)': 639, 'COMM_CODE': 'APP', 'COMM_NAME': 'APPLEWOOD PARK'}
# {'count(COMM_CODE)': 1343, 'COMM_CODE': 'ARB', 'COMM_NAME': 'ARBOUR LAKE'}
# {'count(COMM_CODE)': 1198, 'COMM_CODE': 'ASP', 'COMM_NAME': 'ASPEN WOODS'}
# {'count(COMM_CODE)': 2389, 'COMM_CODE': 'AUB', 'COMM_NAME': 'AUBURN BAY'}
# {'count(COMM_CODE)': 495, 'COMM_CODE': 'BNF', 'COMM_NAME': 'BANFF TRAIL'}
# {'count(COMM_CODE)': 848, 'COMM_CODE': 'BNK', 'COMM_NAME': 'BANKVIEW'}
# {'count(COMM_CODE)': 96, 'COMM_CODE': 'BYV', 'COMM_NAME': 'BAYVIEW'}
# {'count(COMM_CODE)': 1681, 'COMM_CODE': 'BED', 'COMM_NAME': 'BEDDINGTON HEIGHTS'}
# {'count(COMM_CODE)': 74, 'COMM_CODE': 'BEL', 'COMM_NAME': 'BEL-AIRE'}
# {'count(COMM_CODE)': 65, 'COMM_CODE': 'BLM', 'COMM_NAME': 'BELMONT'}
# {'count(COMM_CODE)': 4304, 'COMM_CODE': 'BLN', 'COMM_NAME': 'BELTLINE'}
# {'count(COMM_CODE)': 3, 'COMM_CODE': 'BVD', 'COMM_NAME': 'BELVEDERE'}
# {'count(COMM_CODE)': 122, 'COMM_CODE': 'BDO', 'COMM_NAME': 'BONAVISTA DOWNS'}
# {'count(COMM_CODE)': 1524, 'COMM_CODE': 'BOW', 'COMM_NAME': 'BOWNESS'}
# {'count(COMM_CODE)': 965, 'COMM_CODE': 'BRA', 'COMM_NAME': 'BRAESIDE'}
# {'count(COMM_CODE)': 1167, 'COMM_CODE': 'BRE', 'COMM_NAME': 'BRENTWOOD'}
# {'count(COMM_CODE)': 985, 'COMM_CODE': 'BRD', 'COMM_NAME': 'BRIDGELAND/RIVERSIDE'}
# {'count(COMM_CODE)': 1589, 'COMM_CODE': 'BRI', 'COMM_NAME': 'BRIDLEWOOD'}
# {'count(COMM_CODE)': 121, 'COMM_CODE': 'BRT', 'COMM_NAME': 'BRITANNIA'}
# {'count(COMM_CODE)': 290, 'COMM_CODE': 'CAM', 'COMM_NAME': 'CAMBRIAN HEIGHTS'}
# {'count(COMM_CODE)': 1205, 'COMM_CODE': 'CAN', 'COMM_NAME': 'CANYON MEADOWS'}
# {'count(COMM_CODE)': 603, 'COMM_CODE': 'CAP', 'COMM_NAME': 'CAPITOL HILL'}
# {'count(COMM_CODE)': 288, 'COMM_CODE': 'CAR', 'COMM_NAME': 'CARRINGTON'}
# {'count(COMM_CODE)': 644, 'COMM_CODE': 'CAS', 'COMM_NAME': 'CASTLERIDGE'}
# {'count(COMM_CODE)': 918, 'COMM_CODE': 'CED', 'COMM_NAME': 'CEDARBRAE'}
# {'count(COMM_CODE)': 1581, 'COMM_CODE': 'CHA', 'COMM_NAME': 'CHAPARRAL'}
# {'count(COMM_CODE)': 520, 'COMM_CODE': 'CHW', 'COMM_NAME': 'CHARLESWOOD'}
# {'count(COMM_CODE)': 480, 'COMM_CODE': 'CHN', 'COMM_NAME': 'CHINATOWN'}
# {'count(COMM_CODE)': 202, 'COMM_CODE': 'CHK', 'COMM_NAME': 'CHINOOK PARK'}
# {'count(COMM_CODE)': 280, 'COMM_CODE': 'CHR', 'COMM_NAME': 'CHRISTIE PARK'}
# {'count(COMM_CODE)': 1464, 'COMM_CODE': 'CIT', 'COMM_NAME': 'CITADEL'}
# {'count(COMM_CODE)': 435, 'COMM_CODE': 'CSC', 'COMM_NAME': 'CITYSCAPE'}
# {'count(COMM_CODE)': 305, 'COMM_CODE': 'CLI', 'COMM_NAME': 'CLIFF BUNGALOW'}
# {'count(COMM_CODE)': 733, 'COMM_CODE': 'COA', 'COMM_NAME': 'COACH HILL'}
# {'count(COMM_CODE)': 328, 'COMM_CODE': 'COL', 'COMM_NAME': 'COLLINGWOOD'}
# {'count(COMM_CODE)': 1928, 'COMM_CODE': 'CPF', 'COMM_NAME': 'COPPERFIELD'}
# {'count(COMM_CODE)': 565, 'COMM_CODE': 'COR', 'COMM_NAME': 'CORAL SPRINGS'}
# {'count(COMM_CODE)': 530, 'COMM_CODE': 'CNS', 'COMM_NAME': 'CORNERSTONE'}
# {'count(COMM_CODE)': 882, 'COMM_CODE': 'CGR', 'COMM_NAME': 'COUGAR RIDGE'}
# {'count(COMM_CODE)': 596, 'COMM_CODE': 'COU', 'COMM_NAME': 'COUNTRY HILLS'}
# {'count(COMM_CODE)': 510, 'COMM_CODE': 'CHV', 'COMM_NAME': 'COUNTRY HILLS VILLAGE'}
# {'count(COMM_CODE)': 2111, 'COMM_CODE': 'COV', 'COMM_NAME': 'COVENTRY HILLS'}
# {'count(COMM_CODE)': 2780, 'COMM_CODE': 'CRA', 'COMM_NAME': 'CRANSTON'}
# {'count(COMM_CODE)': 1053, 'COMM_CODE': 'CRE', 'COMM_NAME': 'CRESCENT HEIGHTS'}
# {'count(COMM_CODE)': 284, 'COMM_CODE': 'CRM', 'COMM_NAME': 'CRESTMONT'}
# {'count(COMM_CODE)': 361, 'COMM_CODE': 'CUR', 'COMM_NAME': 'CURRIE BARRACKS'}
# {'count(COMM_CODE)': 1346, 'COMM_CODE': 'DAL', 'COMM_NAME': 'DALHOUSIE'}
# {'count(COMM_CODE)': 559, 'COMM_CODE': 'DRG', 'COMM_NAME': 'DEER RIDGE'}
# {'count(COMM_CODE)': 815, 'COMM_CODE': 'DRN', 'COMM_NAME': 'DEER RUN'}
# {'count(COMM_CODE)': 101, 'COMM_CODE': 'DIA', 'COMM_NAME': 'DIAMOND COVE'}
# {'count(COMM_CODE)': 688, 'COMM_CODE': 'DIS', 'COMM_NAME': 'DISCOVERY RIDGE'}
# {'count(COMM_CODE)': 1872, 'COMM_CODE': 'DDG', 'COMM_NAME': 'DOUGLASDALE/GLEN'}
# {'count(COMM_CODE)': 1521, 'COMM_CODE': 'DOV', 'COMM_NAME': 'DOVER'}
# {'count(COMM_CODE)': 772, 'COMM_CODE': 'DNC', 'COMM_NAME': 'DOWNTOWN COMMERCIAL CORE'}
# {'count(COMM_CODE)': 666, 'COMM_CODE': 'DNE', 'COMM_NAME': 'DOWNTOWN EAST VILLAGE'}
# {'count(COMM_CODE)': 497, 'COMM_CODE': 'DNW', 'COMM_NAME': 'DOWNTOWN WEST END'}
# {'count(COMM_CODE)': 40, 'COMM_CODE': 'EAG', 'COMM_NAME': 'EAGLE RIDGE'}
# {'count(COMM_CODE)': 481, 'COMM_CODE': 'EAU', 'COMM_NAME': 'EAU CLAIRE'}
# {'count(COMM_CODE)': 2047, 'COMM_CODE': 'EDG', 'COMM_NAME': 'EDGEMONT'}
# {'count(COMM_CODE)': 484, 'COMM_CODE': 'EPK', 'COMM_NAME': 'ELBOW PARK'}
# {'count(COMM_CODE)': 281, 'COMM_CODE': 'EYA', 'COMM_NAME': 'ELBOYA'}
# {'count(COMM_CODE)': 906, 'COMM_CODE': 'ERI', 'COMM_NAME': 'ERIN WOODS'}
# {'count(COMM_CODE)': 274, 'COMM_CODE': 'ERL', 'COMM_NAME': 'ERLTON'}
# {'count(COMM_CODE)': 2375, 'COMM_CODE': 'EVN', 'COMM_NAME': 'EVANSTON'}
# {'count(COMM_CODE)': 2830, 'COMM_CODE': 'EVE', 'COMM_NAME': 'EVERGREEN'}
# {'count(COMM_CODE)': 487, 'COMM_CODE': 'FAI', 'COMM_NAME': 'FAIRVIEW'}
# {'count(COMM_CODE)': 1103, 'COMM_CODE': 'FAL', 'COMM_NAME': 'FALCONRIDGE'}
# {'count(COMM_CODE)': 734, 'COMM_CODE': 'FHT', 'COMM_NAME': 'FOREST HEIGHTS'}
# {'count(COMM_CODE)': 832, 'COMM_CODE': 'FLN', 'COMM_NAME': 'FOREST LAWN'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': 'FRA', 'COMM_NAME': 'FRANKLIN'}
# {'count(COMM_CODE)': 257, 'COMM_CODE': 'GAG', 'COMM_NAME': 'GARRISON GREEN'}
# {'count(COMM_CODE)': 693, 'COMM_CODE': 'GAW', 'COMM_NAME': 'GARRISON WOODS'}
# {'count(COMM_CODE)': 909, 'COMM_CODE': 'GLA', 'COMM_NAME': 'GLAMORGAN'}
# {'count(COMM_CODE)': 890, 'COMM_CODE': 'GBK', 'COMM_NAME': 'GLENBROOK'}
# {'count(COMM_CODE)': 382, 'COMM_CODE': 'GDL', 'COMM_NAME': 'GLENDALE'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': 'GPK', 'COMM_NAME': 'GLENMORE PARK'}
# {'count(COMM_CODE)': 317, 'COMM_CODE': 'GRV', 'COMM_NAME': 'GREENVIEW'}
# {'count(COMM_CODE)': 2, 'COMM_CODE': 'GRI', 'COMM_NAME': 'GREENVIEW INDUSTRIAL PARK'}
# {'count(COMM_CODE)': 18, 'COMM_CODE': 'GRE', 'COMM_NAME': 'GREENWOOD/GREENBRIAR'}
# {'count(COMM_CODE)': 926, 'COMM_CODE': 'HAM', 'COMM_NAME': 'HAMPTONS'}
# {'count(COMM_CODE)': 1013, 'COMM_CODE': 'HAR', 'COMM_NAME': 'HARVEST HILLS'}
# {'count(COMM_CODE)': 1271, 'COMM_CODE': 'HAW', 'COMM_NAME': 'HAWKWOOD'}
# {'count(COMM_CODE)': 1277, 'COMM_CODE': 'HAY', 'COMM_NAME': 'HAYSBORO'}
# {'count(COMM_CODE)': 1440, 'COMM_CODE': 'HID', 'COMM_NAME': 'HIDDEN VALLEY'}
# {'count(COMM_CODE)': 608, 'COMM_CODE': 'HPK', 'COMM_NAME': 'HIGHLAND PARK'}
# {'count(COMM_CODE)': 320, 'COMM_CODE': 'HIW', 'COMM_NAME': 'HIGHWOOD'}
# {'count(COMM_CODE)': 1059, 'COMM_CODE': 'HIL', 'COMM_NAME': 'HILLHURST'}
# {'count(COMM_CODE)': 2, 'COMM_CODE': 'HKS', 'COMM_NAME': 'HOTCHKISS'}
# {'count(COMM_CODE)': 410, 'COMM_CODE': 'HOU', 'COMM_NAME': 'HOUNSFIELD HEIGHTS/BRIAR HILL'}
# {'count(COMM_CODE)': 1782, 'COMM_CODE': 'HUN', 'COMM_NAME': 'HUNTINGTON HILLS'}
# {'count(COMM_CODE)': 709, 'COMM_CODE': 'ING', 'COMM_NAME': 'INGLEWOOD'}
# {'count(COMM_CODE)': 223, 'COMM_CODE': 'KEL', 'COMM_NAME': 'KELVIN GROVE'}
# {'count(COMM_CODE)': 1418, 'COMM_CODE': 'KIL', 'COMM_NAME': 'KILLARNEY/GLENGARRY'}
# {'count(COMM_CODE)': 939, 'COMM_CODE': 'KCA', 'COMM_NAME': 'KINCORA'}
# {'count(COMM_CODE)': 504, 'COMM_CODE': 'KIN', 'COMM_NAME': 'KINGSLAND'}
# {'count(COMM_CODE)': 1577, 'COMM_CODE': 'LKB', 'COMM_NAME': 'LAKE BONAVISTA'}
# {'count(COMM_CODE)': 779, 'COMM_CODE': 'LKV', 'COMM_NAME': 'LAKEVIEW'}
# {'count(COMM_CODE)': 1251, 'COMM_CODE': 'LEG', 'COMM_NAME': 'LEGACY'}
# {'count(COMM_CODE)': 382, 'COMM_CODE': 'LPK', 'COMM_NAME': 'LINCOLN PARK'}
# {'count(COMM_CODE)': 453, 'COMM_CODE': 'LIV', 'COMM_NAME': 'LIVINGSTON'}
# {'count(COMM_CODE)': 535, 'COMM_CODE': 'LMR', 'COMM_NAME': 'LOWER MOUNT ROYAL'}
# {'count(COMM_CODE)': 646, 'COMM_CODE': 'MAC', 'COMM_NAME': 'MACEWAN'}
# {'count(COMM_CODE)': 2124, 'COMM_CODE': 'MAH', 'COMM_NAME': 'MAHOGANY'}
# {'count(COMM_CODE)': 72, 'COMM_CODE': 'MAN', 'COMM_NAME': 'MANCHESTER'}
# {'count(COMM_CODE)': 331, 'COMM_CODE': 'MPL', 'COMM_NAME': 'MAPLE RIDGE'}
# {'count(COMM_CODE)': 1145, 'COMM_CODE': 'MRL', 'COMM_NAME': 'MARLBOROUGH'}
# {'count(COMM_CODE)': 1061, 'COMM_CODE': 'MPK', 'COMM_NAME': 'MARLBOROUGH PARK'}
# {'count(COMM_CODE)': 1436, 'COMM_CODE': 'MRT', 'COMM_NAME': 'MARTINDALE'}
# {'count(COMM_CODE)': 57, 'COMM_CODE': 'MAF', 'COMM_NAME': 'MAYFAIR'}
# {'count(COMM_CODE)': 723, 'COMM_CODE': 'MAL', 'COMM_NAME': 'MAYLAND HEIGHTS'}
# {'count(COMM_CODE)': 1776, 'COMM_CODE': 'MCK', 'COMM_NAME': 'MCKENZIE LAKE'}
# {'count(COMM_CODE)': 2849, 'COMM_CODE': 'MCT', 'COMM_NAME': 'MCKENZIE TOWNE'}
# {'count(COMM_CODE)': 102, 'COMM_CODE': 'MEA', 'COMM_NAME': 'MEADOWLARK PARK'}
# {'count(COMM_CODE)': 3, 'COMM_CODE': 'MDH', 'COMM_NAME': 'MEDICINE HILL'}
# {'count(COMM_CODE)': 893, 'COMM_CODE': 'MID', 'COMM_NAME': 'MIDNAPORE'}
# {'count(COMM_CODE)': 1053, 'COMM_CODE': 'MLR', 'COMM_NAME': 'MILLRISE'}
# {'count(COMM_CODE)': 826, 'COMM_CODE': 'MIS', 'COMM_NAME': 'MISSION'}
# {'count(COMM_CODE)': 1086, 'COMM_CODE': 'MOR', 'COMM_NAME': 'MONTEREY PARK'}
# {'count(COMM_CODE)': 623, 'COMM_CODE': 'MON', 'COMM_NAME': 'MONTGOMERY'}
# {'count(COMM_CODE)': 901, 'COMM_CODE': 'MOP', 'COMM_NAME': 'MOUNT PLEASANT'}
# {'count(COMM_CODE)': 1802, 'COMM_CODE': 'NEB', 'COMM_NAME': 'NEW BRIGHTON'}
# {'count(COMM_CODE)': 1351, 'COMM_CODE': 'NOL', 'COMM_NAME': 'NOLAN HILL'}
# {'count(COMM_CODE)': 371, 'COMM_CODE': 'NGM', 'COMM_NAME': 'NORTH GLENMORE PARK'}
# {'count(COMM_CODE)': 312, 'COMM_CODE': 'NHV', 'COMM_NAME': 'NORTH HAVEN'}
# {'count(COMM_CODE)': 93, 'COMM_CODE': 'NHU', 'COMM_NAME': 'NORTH HAVEN UPPER'}
# {'count(COMM_CODE)': 904, 'COMM_CODE': 'OAK', 'COMM_NAME': 'OAKRIDGE'}
# {'count(COMM_CODE)': 1134, 'COMM_CODE': 'OGD', 'COMM_NAME': 'OGDEN'}
# {'count(COMM_CODE)': 434, 'COMM_CODE': 'PAL', 'COMM_NAME': 'PALLISER'}
# {'count(COMM_CODE)': 3316, 'COMM_CODE': 'PAN', 'COMM_NAME': 'PANORAMA HILLS'}
# {'count(COMM_CODE)': 361, 'COMM_CODE': 'PKD', 'COMM_NAME': 'PARKDALE'}
# {'count(COMM_CODE)': 286, 'COMM_CODE': 'PKH', 'COMM_NAME': 'PARKHILL/STANLEY PARK'}
# {'count(COMM_CODE)': 614, 'COMM_CODE': 'PKL', 'COMM_NAME': 'PARKLAND'}
# {'count(COMM_CODE)': 782, 'COMM_CODE': 'PAT', 'COMM_NAME': 'PATTERSON'}
# {'count(COMM_CODE)': 1044, 'COMM_CODE': 'PEN', 'COMM_NAME': 'PENBROOKE MEADOWS'}
# {'count(COMM_CODE)': 7, 'COMM_CODE': 'PCK', 'COMM_NAME': 'PINE CREEK'}
# {'count(COMM_CODE)': 1204, 'COMM_CODE': 'PIN', 'COMM_NAME': 'PINERIDGE'}
# {'count(COMM_CODE)': 312, 'COMM_CODE': 'POI', 'COMM_NAME': 'POINT MCKAY'}
# {'count(COMM_CODE)': 165, 'COMM_CODE': 'PUM', 'COMM_NAME': 'PUMP HILL'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': 'QPK', 'COMM_NAME': 'QUEENS PARK VILLAGE'}
# {'count(COMM_CODE)': 696, 'COMM_CODE': 'QLD', 'COMM_NAME': 'QUEENSLAND'}
# {'count(COMM_CODE)': 324, 'COMM_CODE': 'RAM', 'COMM_NAME': 'RAMSAY'}
# {'count(COMM_CODE)': 1071, 'COMM_CODE': 'RAN', 'COMM_NAME': 'RANCHLANDS'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': 'RVW', 'COMM_NAME': 'RANGEVIEW'}
# {'count(COMM_CODE)': 158, 'COMM_CODE': 'RED', 'COMM_NAME': 'RED CARPET/MOUNTVIEW MOBILE PARK'}
# {'count(COMM_CODE)': 805, 'COMM_CODE': 'RSN', 'COMM_NAME': 'REDSTONE'}
# {'count(COMM_CODE)': 1407, 'COMM_CODE': 'REN', 'COMM_NAME': 'RENFREW'}
# {'count(COMM_CODE)': 4, 'COMM_CODE': '01C', 'COMM_NAME': 'RESIDUAL WARD 1 - CALGARY WEST'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '01D', 'COMM_NAME': 'RESIDUAL WARD 1 - CANADA OLYMPIC PARK'}
# {'count(COMM_CODE)': 35, 'COMM_CODE': '01F', 'COMM_NAME': 'RESIDUAL WARD 1 - SUB AREA 1F'}
# {'count(COMM_CODE)': 4, 'COMM_CODE': '01H', 'COMM_NAME': 'RESIDUAL WARD 1 - SUB AREA 1H'}
# {'count(COMM_CODE)': 9, 'COMM_CODE': '10A', 'COMM_NAME': 'RESIDUAL WARD 10 - SUB AREA 10A'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '10B', 'COMM_NAME': 'RESIDUAL WARD 10 - SUB AREA 10B'}
# {'count(COMM_CODE)': 17, 'COMM_CODE': '10C', 'COMM_NAME': 'RESIDUAL WARD 10 - SUB AREA 10C'}
# {'count(COMM_CODE)': 24, 'COMM_CODE': '12A', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12A'}
# {'count(COMM_CODE)': 3, 'COMM_CODE': '12B', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12B'}
# {'count(COMM_CODE)': 12, 'COMM_CODE': '12C', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12C'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '12I', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12I'}
# {'count(COMM_CODE)': 7, 'COMM_CODE': '12J', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12J'}
# {'count(COMM_CODE)': 4, 'COMM_CODE': '12L', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12L'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '13C', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13C'}
# {'count(COMM_CODE)': 2, 'COMM_CODE': '13D', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13D'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '13E', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13E'}
# {'count(COMM_CODE)': 4, 'COMM_CODE': '13F', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13F'}
# {'count(COMM_CODE)': 3, 'COMM_CODE': '13G', 'COMM_NAME': 'RESIDUAL WARD 13 - SUB AREA 13G'}
# {'count(COMM_CODE)': 8, 'COMM_CODE': '14V', 'COMM_NAME': 'RESIDUAL WARD 14 - SUB AREA 14V'}
# {'count(COMM_CODE)': 4, 'COMM_CODE': '02L', 'COMM_NAME': 'RESIDUAL WARD 2 - SUB AREA 02L'}
# {'count(COMM_CODE)': 2, 'COMM_CODE': '02C', 'COMM_NAME': 'RESIDUAL WARD 2 - SUB AREA 2C'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '02K', 'COMM_NAME': 'RESIDUAL WARD 2 - SUB AREA 2K'}
# {'count(COMM_CODE)': 2, 'COMM_CODE': '03D', 'COMM_NAME': 'RESIDUAL WARD 3 - SUB AREA 3D'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '03S', 'COMM_NAME': 'RESIDUAL WARD 3 - SUB AREA 3S'}
# {'count(COMM_CODE)': 6, 'COMM_CODE': '03W', 'COMM_NAME': 'RESIDUAL WARD 3 - SUB AREA 3W'}
# {'count(COMM_CODE)': 2, 'COMM_CODE': '05B', 'COMM_NAME': 'RESIDUAL WARD 5 - SUB AREA 5B'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '05C', 'COMM_NAME': 'RESIDUAL WARD 5 - SUB AREA 5C'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '05E', 'COMM_NAME': 'RESIDUAL WARD 5 - SUB AREA 5E'}
# {'count(COMM_CODE)': 6, 'COMM_CODE': '06A', 'COMM_NAME': 'RESIDUAL WARD 6 - SUB AREA 6A'}
# {'count(COMM_CODE)': 2, 'COMM_CODE': '09K', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9K'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '09N', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9N'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '09P', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9P'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': '09Q', 'COMM_NAME': 'RESIDUAL WARD 9 - SUB AREA 9Q'}
# {'count(COMM_CODE)': 766, 'COMM_CODE': 'RIC', 'COMM_NAME': 'RICHMOND'}
# {'count(COMM_CODE)': 180, 'COMM_CODE': 'RID', 'COMM_NAME': 'RIDEAU PARK'}
# {'count(COMM_CODE)': 1290, 'COMM_CODE': 'RIV', 'COMM_NAME': 'RIVERBEND'}
# {'count(COMM_CODE)': 1251, 'COMM_CODE': 'ROC', 'COMM_NAME': 'ROCKY RIDGE'}
# {'count(COMM_CODE)': 212, 'COMM_CODE': 'RDL', 'COMM_NAME': 'ROSEDALE'}
# {'count(COMM_CODE)': 164, 'COMM_CODE': 'RMT', 'COMM_NAME': 'ROSEMONT'}
# {'count(COMM_CODE)': 358, 'COMM_CODE': 'RCK', 'COMM_NAME': 'ROSSCARROCK'}
# {'count(COMM_CODE)': 58, 'COMM_CODE': 'ROX', 'COMM_NAME': 'ROXBORO'}
# {'count(COMM_CODE)': 1646, 'COMM_CODE': 'ROY', 'COMM_NAME': 'ROYAL OAK'}
# {'count(COMM_CODE)': 1213, 'COMM_CODE': 'RUN', 'COMM_NAME': 'RUNDLE'}
# {'count(COMM_CODE)': 302, 'COMM_CODE': 'RUT', 'COMM_NAME': 'RUTLAND PARK'}
# {'count(COMM_CODE)': 2268, 'COMM_CODE': 'SAD', 'COMM_NAME': 'SADDLE RIDGE'}
# {'count(COMM_CODE)': 3, 'COMM_CODE': 'SRI', 'COMM_NAME': 'SADDLE RIDGE INDUSTRIAL'}
# {'count(COMM_CODE)': 1263, 'COMM_CODE': 'SGH', 'COMM_NAME': 'SAGE HILL'}
# {'count(COMM_CODE)': 790, 'COMM_CODE': 'SAN', 'COMM_NAME': 'SANDSTONE VALLEY'}
# {'count(COMM_CODE)': 128, 'COMM_CODE': 'SCA', 'COMM_NAME': 'SCARBORO'}
# {'count(COMM_CODE)': 70, 'COMM_CODE': 'SSW', 'COMM_NAME': 'SCARBORO/SUNALTA WEST'}
# {'count(COMM_CODE)': 1181, 'COMM_CODE': 'SCE', 'COMM_NAME': 'SCENIC ACRES'}
# {'count(COMM_CODE)': 232, 'COMM_CODE': 'SET', 'COMM_NAME': 'SETON'}
# {'count(COMM_CODE)': 251, 'COMM_CODE': 'SHG', 'COMM_NAME': 'SHAGANAPPI'}
# {'count(COMM_CODE)': 305, 'COMM_CODE': 'SHS', 'COMM_NAME': 'SHAWNEE SLOPES'}
# {'count(COMM_CODE)': 1237, 'COMM_CODE': 'SHN', 'COMM_NAME': 'SHAWNESSY'}
# {'count(COMM_CODE)': 5, 'COMM_CODE': 'SHI', 'COMM_NAME': 'SHEPARD INDUSTRIAL'}
# {'count(COMM_CODE)': 877, 'COMM_CODE': 'SHW', 'COMM_NAME': 'SHERWOOD'}
# {'count(COMM_CODE)': 2095, 'COMM_CODE': 'SIG', 'COMM_NAME': 'SIGNAL HILL'}
# {'count(COMM_CODE)': 1271, 'COMM_CODE': 'SIL', 'COMM_NAME': 'SILVER SPRINGS'}
# {'count(COMM_CODE)': 1034, 'COMM_CODE': 'SVO', 'COMM_NAME': 'SILVERADO'}
# {'count(COMM_CODE)': 1337, 'COMM_CODE': 'SKR', 'COMM_NAME': 'SKYVIEW RANCH'}
# {'count(COMM_CODE)': 1150, 'COMM_CODE': 'SOM', 'COMM_NAME': 'SOMERSET'}
# {'count(COMM_CODE)': 724, 'COMM_CODE': 'SOC', 'COMM_NAME': 'SOUTH CALGARY'}
# {'count(COMM_CODE)': 228, 'COMM_CODE': 'SOV', 'COMM_NAME': 'SOUTHVIEW'}
# {'count(COMM_CODE)': 853, 'COMM_CODE': 'SOW', 'COMM_NAME': 'SOUTHWOOD'}
# {'count(COMM_CODE)': 1397, 'COMM_CODE': 'SPH', 'COMM_NAME': 'SPRINGBANK HILL'}
# {'count(COMM_CODE)': 651, 'COMM_CODE': 'SPR', 'COMM_NAME': 'SPRUCE CLIFF'}
# {'count(COMM_CODE)': 207, 'COMM_CODE': 'STA', 'COMM_NAME': 'ST. ANDREWS HEIGHTS'}
# {'count(COMM_CODE)': 1, 'COMM_CODE': 'ST4', 'COMM_NAME': 'STONEY 4'}
# {'count(COMM_CODE)': 896, 'COMM_CODE': 'STR', 'COMM_NAME': 'STRATHCONA PARK'}
# {'count(COMM_CODE)': 527, 'COMM_CODE': 'SNA', 'COMM_NAME': 'SUNALTA'}
# {'count(COMM_CODE)': 1238, 'COMM_CODE': 'SDC', 'COMM_NAME': 'SUNDANCE'}
# {'count(COMM_CODE)': 693, 'COMM_CODE': 'SSD', 'COMM_NAME': 'SUNNYSIDE'}
# {'count(COMM_CODE)': 1646, 'COMM_CODE': 'TAR', 'COMM_NAME': 'TARADALE'}
# {'count(COMM_CODE)': 1314, 'COMM_CODE': 'TEM', 'COMM_NAME': 'TEMPLE'}
# {'count(COMM_CODE)': 1106, 'COMM_CODE': 'THO', 'COMM_NAME': 'THORNCLIFFE'}
# {'count(COMM_CODE)': 2611, 'COMM_CODE': 'TUS', 'COMM_NAME': 'TUSCANY'}
# {'count(COMM_CODE)': 792, 'COMM_CODE': 'TUX', 'COMM_NAME': 'TUXEDO PARK'}
# {'count(COMM_CODE)': 21, 'COMM_CODE': 'UND', 'COMM_NAME': 'UNIVERSITY DISTRICT'}
# {'count(COMM_CODE)': 209, 'COMM_CODE': 'UNI', 'COMM_NAME': 'UNIVERSITY HEIGHTS'}
# {'count(COMM_CODE)': 4, 'COMM_CODE': 'UOC', 'COMM_NAME': 'UNIVERSITY OF CALGARY'}
# {'count(COMM_CODE)': 346, 'COMM_CODE': 'UMR', 'COMM_NAME': 'UPPER MOUNT ROYAL'}
# {'count(COMM_CODE)': 748, 'COMM_CODE': 'VAL', 'COMM_NAME': 'VALLEY RIDGE'}
# {'count(COMM_CODE)': 2, 'COMM_CODE': 'VAF', 'COMM_NAME': 'VALLEYFIELD'}
# {'count(COMM_CODE)': 1959, 'COMM_CODE': 'VAR', 'COMM_NAME': 'VARSITY'}
# {'count(COMM_CODE)': 239, 'COMM_CODE': 'VIS', 'COMM_NAME': 'VISTA HEIGHTS'}
# {'count(COMM_CODE)': 951, 'COMM_CODE': 'WAL', 'COMM_NAME': 'WALDEN'}
# {'count(COMM_CODE)': 1058, 'COMM_CODE': 'WHL', 'COMM_NAME': 'WEST HILLHURST'}
# {'count(COMM_CODE)': 1417, 'COMM_CODE': 'WSP', 'COMM_NAME': 'WEST SPRINGS'}
# {'count(COMM_CODE)': 456, 'COMM_CODE': 'WGT', 'COMM_NAME': 'WESTGATE'}
# {'count(COMM_CODE)': 1352, 'COMM_CODE': 'WHI', 'COMM_NAME': 'WHITEHORN'}
# {'count(COMM_CODE)': 368, 'COMM_CODE': 'WLD', 'COMM_NAME': 'WILDWOOD'}
# {'count(COMM_CODE)': 748, 'COMM_CODE': 'WIL', 'COMM_NAME': 'WILLOW PARK'}
# {'count(COMM_CODE)': 683, 'COMM_CODE': 'WND', 'COMM_NAME': 'WINDSOR PARK'}
# {'count(COMM_CODE)': 632, 'COMM_CODE': 'WIN', 'COMM_NAME': 'WINSTON HEIGHTS/MOUNTVIEW'}
# {'count(COMM_CODE)': 1335, 'COMM_CODE': 'WBN', 'COMM_NAME': 'WOODBINE'}
# {'count(COMM_CODE)': 793, 'COMM_CODE': 'WOO', 'COMM_NAME': 'WOODLANDS'}
# {'count(COMM_CODE)': 4, 'COMM_CODE': 'YKV', 'COMM_NAME': 'YORKVILLE'}
# True

# %% [markdown]
# Getting the total property count for each community allows us to get a general idea on the sizes of each community compared to one another. This will also be useful when we are comparing property assessment values/counts for each community with other factors from our other datasets such as demographics and crime, since we need to take into account the size differences between the communities (This helps us when we look into our guiding question which involves looking at the effect of population density and property assessments/density).
#
# Along with the threshold that was decided from the query above (100,000), we decided from this query that we are only considering communities with a count of 10 or more property assessments present. This is because communities with a count of less than 10 is not really considered a community in our eyes. The reason the community property count for some communities may be so low is that it is an extremely new community or they are the "residual ward communities" (mentioned these before and we are not using them anyways) or are possible typos. So having these two restrictions in place (count of 10 or more and a threshold of 100000 or more for property assessment values) helps us gather consistent data as you will see in the next few queries (hint: we grab averages, so having a count of 10 or more allows us to actually get an average that isnt just from a single property).

# %% [markdown]
# ## Query 4

# %%
#Get the average property assessment values per each community above the chosen property assessment value threshold

read_cursor = myconnection.cursor(buffered=True, dictionary=True)

query_string = ("SELECT avg(ASSESSED_VALUE), COMM_CODE, COMM_NAME FROM property_data WHERE ASSESSED_VALUE > 100000 GROUP BY COMM_NAME HAVING count(COMM_CODE) > 10;")

read_cursor.execute(query_string)

for (prop_value) in read_cursor:
    print(prop_value)
    
read_cursor.close()
# Out:
# {'avg(ASSESSED_VALUE)': Decimal('297105.4422'), 'COMM_CODE': 'ABB', 'COMM_NAME': 'ABBEYDALE'}
# {'avg(ASSESSED_VALUE)': Decimal('385040.1691'), 'COMM_CODE': 'ACA', 'COMM_NAME': 'ACADIA'}
# {'avg(ASSESSED_VALUE)': Decimal('483790.6648'), 'COMM_CODE': 'ALB', 'COMM_NAME': 'ALBERT PARK/RADISSON HEIGHTS'}
# {'avg(ASSESSED_VALUE)': Decimal('846348.0154'), 'COMM_CODE': 'ALT', 'COMM_NAME': 'ALTADORE'}
# {'avg(ASSESSED_VALUE)': Decimal('380939.7496'), 'COMM_CODE': 'APP', 'COMM_NAME': 'APPLEWOOD PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('494914.7431'), 'COMM_CODE': 'ARB', 'COMM_NAME': 'ARBOUR LAKE'}
# {'avg(ASSESSED_VALUE)': Decimal('921439.0651'), 'COMM_CODE': 'ASP', 'COMM_NAME': 'ASPEN WOODS'}
# {'avg(ASSESSED_VALUE)': Decimal('503028.0452'), 'COMM_CODE': 'AUB', 'COMM_NAME': 'AUBURN BAY'}
# {'avg(ASSESSED_VALUE)': Decimal('680679.7980'), 'COMM_CODE': 'BNF', 'COMM_NAME': 'BANFF TRAIL'}
# {'avg(ASSESSED_VALUE)': Decimal('408836.6745'), 'COMM_CODE': 'BNK', 'COMM_NAME': 'BANKVIEW'}
# {'avg(ASSESSED_VALUE)': Decimal('1154312.5000'), 'COMM_CODE': 'BYV', 'COMM_NAME': 'BAYVIEW'}
# {'avg(ASSESSED_VALUE)': Decimal('352208.8043'), 'COMM_CODE': 'BED', 'COMM_NAME': 'BEDDINGTON HEIGHTS'}
# {'avg(ASSESSED_VALUE)': Decimal('2046222.9730'), 'COMM_CODE': 'BEL', 'COMM_NAME': 'BEL-AIRE'}
# {'avg(ASSESSED_VALUE)': Decimal('695169.2308'), 'COMM_CODE': 'BLM', 'COMM_NAME': 'BELMONT'}
# {'avg(ASSESSED_VALUE)': Decimal('467281.9470'), 'COMM_CODE': 'BLN', 'COMM_NAME': 'BELTLINE'}
# {'avg(ASSESSED_VALUE)': Decimal('428200.8197'), 'COMM_CODE': 'BDO', 'COMM_NAME': 'BONAVISTA DOWNS'}
# {'avg(ASSESSED_VALUE)': Decimal('466765.0919'), 'COMM_CODE': 'BOW', 'COMM_NAME': 'BOWNESS'}
# {'avg(ASSESSED_VALUE)': Decimal('348816.0622'), 'COMM_CODE': 'BRA', 'COMM_NAME': 'BRAESIDE'}
# {'avg(ASSESSED_VALUE)': Decimal('490552.2708'), 'COMM_CODE': 'BRE', 'COMM_NAME': 'BRENTWOOD'}
# {'avg(ASSESSED_VALUE)': Decimal('537938.0711'), 'COMM_CODE': 'BRD', 'COMM_NAME': 'BRIDGELAND/RIVERSIDE'}
# {'avg(ASSESSED_VALUE)': Decimal('366908.7476'), 'COMM_CODE': 'BRI', 'COMM_NAME': 'BRIDLEWOOD'}
# {'avg(ASSESSED_VALUE)': Decimal('1808177.6860'), 'COMM_CODE': 'BRT', 'COMM_NAME': 'BRITANNIA'}
# {'avg(ASSESSED_VALUE)': Decimal('610020.6897'), 'COMM_CODE': 'CAM', 'COMM_NAME': 'CAMBRIAN HEIGHTS'}
# {'avg(ASSESSED_VALUE)': Decimal('433511.6183'), 'COMM_CODE': 'CAN', 'COMM_NAME': 'CANYON MEADOWS'}
# {'avg(ASSESSED_VALUE)': Decimal('606813.4328'), 'COMM_CODE': 'CAP', 'COMM_NAME': 'CAPITOL HILL'}
# {'avg(ASSESSED_VALUE)': Decimal('609397.5694'), 'COMM_CODE': 'CAR', 'COMM_NAME': 'CARRINGTON'}
# {'avg(ASSESSED_VALUE)': Decimal('325029.5031'), 'COMM_CODE': 'CAS', 'COMM_NAME': 'CASTLERIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('388822.4401'), 'COMM_CODE': 'CED', 'COMM_NAME': 'CEDARBRAE'}
# {'avg(ASSESSED_VALUE)': Decimal('488356.4200'), 'COMM_CODE': 'CHA', 'COMM_NAME': 'CHAPARRAL'}
# {'avg(ASSESSED_VALUE)': Decimal('643446.1538'), 'COMM_CODE': 'CHW', 'COMM_NAME': 'CHARLESWOOD'}
# {'avg(ASSESSED_VALUE)': Decimal('536636.4583'), 'COMM_CODE': 'CHN', 'COMM_NAME': 'CHINATOWN'}
# {'avg(ASSESSED_VALUE)': Decimal('705465.3465'), 'COMM_CODE': 'CHK', 'COMM_NAME': 'CHINOOK PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('661883.9286'), 'COMM_CODE': 'CHR', 'COMM_NAME': 'CHRISTIE PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('421652.6639'), 'COMM_CODE': 'CIT', 'COMM_NAME': 'CITADEL'}
# {'avg(ASSESSED_VALUE)': Decimal('466416.0920'), 'COMM_CODE': 'CSC', 'COMM_NAME': 'CITYSCAPE'}
# {'avg(ASSESSED_VALUE)': Decimal('500506.5574'), 'COMM_CODE': 'CLI', 'COMM_NAME': 'CLIFF BUNGALOW'}
# {'avg(ASSESSED_VALUE)': Decimal('405701.2278'), 'COMM_CODE': 'COA', 'COMM_NAME': 'COACH HILL'}
# {'avg(ASSESSED_VALUE)': Decimal('664278.9634'), 'COMM_CODE': 'COL', 'COMM_NAME': 'COLLINGWOOD'}
# {'avg(ASSESSED_VALUE)': Decimal('367600.1037'), 'COMM_CODE': 'CPF', 'COMM_NAME': 'COPPERFIELD'}
# {'avg(ASSESSED_VALUE)': Decimal('473138.9381'), 'COMM_CODE': 'COR', 'COMM_NAME': 'CORAL SPRINGS'}
# {'avg(ASSESSED_VALUE)': Decimal('451181.1321'), 'COMM_CODE': 'CNS', 'COMM_NAME': 'CORNERSTONE'}
# {'avg(ASSESSED_VALUE)': Decimal('607551.0204'), 'COMM_CODE': 'CGR', 'COMM_NAME': 'COUGAR RIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('362675.3356'), 'COMM_CODE': 'COU', 'COMM_NAME': 'COUNTRY HILLS'}
# {'avg(ASSESSED_VALUE)': Decimal('284063.7255'), 'COMM_CODE': 'CHV', 'COMM_NAME': 'COUNTRY HILLS VILLAGE'}
# {'avg(ASSESSED_VALUE)': Decimal('388978.2094'), 'COMM_CODE': 'COV', 'COMM_NAME': 'COVENTRY HILLS'}
# {'avg(ASSESSED_VALUE)': Decimal('495915.4676'), 'COMM_CODE': 'CRA', 'COMM_NAME': 'CRANSTON'}
# {'avg(ASSESSED_VALUE)': Decimal('513371.7949'), 'COMM_CODE': 'CRE', 'COMM_NAME': 'CRESCENT HEIGHTS'}
# {'avg(ASSESSED_VALUE)': Decimal('619112.6761'), 'COMM_CODE': 'CRM', 'COMM_NAME': 'CRESTMONT'}
# {'avg(ASSESSED_VALUE)': Decimal('1082416.8975'), 'COMM_CODE': 'CUR', 'COMM_NAME': 'CURRIE BARRACKS'}
# {'avg(ASSESSED_VALUE)': Decimal('416811.6642'), 'COMM_CODE': 'DAL', 'COMM_NAME': 'DALHOUSIE'}
# {'avg(ASSESSED_VALUE)': Decimal('363823.7925'), 'COMM_CODE': 'DRG', 'COMM_NAME': 'DEER RIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('385960.7362'), 'COMM_CODE': 'DRN', 'COMM_NAME': 'DEER RUN'}
# {'avg(ASSESSED_VALUE)': Decimal('596202.9703'), 'COMM_CODE': 'DIA', 'COMM_NAME': 'DIAMOND COVE'}
# {'avg(ASSESSED_VALUE)': Decimal('640472.3837'), 'COMM_CODE': 'DIS', 'COMM_NAME': 'DISCOVERY RIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('531087.3397'), 'COMM_CODE': 'DDG', 'COMM_NAME': 'DOUGLASDALE/GLEN'}
# {'avg(ASSESSED_VALUE)': Decimal('318306.0487'), 'COMM_CODE': 'DOV', 'COMM_NAME': 'DOVER'}
# {'avg(ASSESSED_VALUE)': Decimal('716147.6684'), 'COMM_CODE': 'DNC', 'COMM_NAME': 'DOWNTOWN COMMERCIAL CORE'}
# {'avg(ASSESSED_VALUE)': Decimal('584072.8228'), 'COMM_CODE': 'DNE', 'COMM_NAME': 'DOWNTOWN EAST VILLAGE'}
# {'avg(ASSESSED_VALUE)': Decimal('350953.7223'), 'COMM_CODE': 'DNW', 'COMM_NAME': 'DOWNTOWN WEST END'}
# {'avg(ASSESSED_VALUE)': Decimal('1778725.0000'), 'COMM_CODE': 'EAG', 'COMM_NAME': 'EAGLE RIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('712232.8482'), 'COMM_CODE': 'EAU', 'COMM_NAME': 'EAU CLAIRE'}
# {'avg(ASSESSED_VALUE)': Decimal('567857.8407'), 'COMM_CODE': 'EDG', 'COMM_NAME': 'EDGEMONT'}
# {'avg(ASSESSED_VALUE)': Decimal('1549903.9256'), 'COMM_CODE': 'EPK', 'COMM_NAME': 'ELBOW PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('834583.6299'), 'COMM_CODE': 'EYA', 'COMM_NAME': 'ELBOYA'}
# {'avg(ASSESSED_VALUE)': Decimal('304573.3996'), 'COMM_CODE': 'ERI', 'COMM_NAME': 'ERIN WOODS'}
# {'avg(ASSESSED_VALUE)': Decimal('493140.5109'), 'COMM_CODE': 'ERL', 'COMM_NAME': 'ERLTON'}
# {'avg(ASSESSED_VALUE)': Decimal('452462.9474'), 'COMM_CODE': 'EVN', 'COMM_NAME': 'EVANSTON'}
# {'avg(ASSESSED_VALUE)': Decimal('473419.7880'), 'COMM_CODE': 'EVE', 'COMM_NAME': 'EVERGREEN'}
# {'avg(ASSESSED_VALUE)': Decimal('468471.2526'), 'COMM_CODE': 'FAI', 'COMM_NAME': 'FAIRVIEW'}
# {'avg(ASSESSED_VALUE)': Decimal('318276.5186'), 'COMM_CODE': 'FAL', 'COMM_NAME': 'FALCONRIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('282537.4659'), 'COMM_CODE': 'FHT', 'COMM_NAME': 'FOREST HEIGHTS'}
# {'avg(ASSESSED_VALUE)': Decimal('366582.9327'), 'COMM_CODE': 'FLN', 'COMM_NAME': 'FOREST LAWN'}
# {'avg(ASSESSED_VALUE)': Decimal('733478.5992'), 'COMM_CODE': 'GAG', 'COMM_NAME': 'GARRISON GREEN'}
# {'avg(ASSESSED_VALUE)': Decimal('549154.4012'), 'COMM_CODE': 'GAW', 'COMM_NAME': 'GARRISON WOODS'}
# {'avg(ASSESSED_VALUE)': Decimal('403273.3773'), 'COMM_CODE': 'GLA', 'COMM_NAME': 'GLAMORGAN'}
# {'avg(ASSESSED_VALUE)': Decimal('498061.2360'), 'COMM_CODE': 'GBK', 'COMM_NAME': 'GLENBROOK'}
# {'avg(ASSESSED_VALUE)': Decimal('623445.0262'), 'COMM_CODE': 'GDL', 'COMM_NAME': 'GLENDALE'}
# {'avg(ASSESSED_VALUE)': Decimal('282490.5363'), 'COMM_CODE': 'GRV', 'COMM_NAME': 'GREENVIEW'}
# {'avg(ASSESSED_VALUE)': Decimal('3583583.3333'), 'COMM_CODE': 'GRE', 'COMM_NAME': 'GREENWOOD/GREENBRIAR'}
# {'avg(ASSESSED_VALUE)': Decimal('686707.3434'), 'COMM_CODE': 'HAM', 'COMM_NAME': 'HAMPTONS'}
# {'avg(ASSESSED_VALUE)': Decimal('405278.3810'), 'COMM_CODE': 'HAR', 'COMM_NAME': 'HARVEST HILLS'}
# {'avg(ASSESSED_VALUE)': Decimal('506086.5460'), 'COMM_CODE': 'HAW', 'COMM_NAME': 'HAWKWOOD'}
# {'avg(ASSESSED_VALUE)': Decimal('357640.5638'), 'COMM_CODE': 'HAY', 'COMM_NAME': 'HAYSBORO'}
# {'avg(ASSESSED_VALUE)': Decimal('444843.7500'), 'COMM_CODE': 'HID', 'COMM_NAME': 'HIDDEN VALLEY'}
# {'avg(ASSESSED_VALUE)': Decimal('488778.7829'), 'COMM_CODE': 'HPK', 'COMM_NAME': 'HIGHLAND PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('500179.6875'), 'COMM_CODE': 'HIW', 'COMM_NAME': 'HIGHWOOD'}
# {'avg(ASSESSED_VALUE)': Decimal('668241.7375'), 'COMM_CODE': 'HIL', 'COMM_NAME': 'HILLHURST'}
# {'avg(ASSESSED_VALUE)': Decimal('1044696.3415'), 'COMM_CODE': 'HOU', 'COMM_NAME': 'HOUNSFIELD HEIGHTS/BRIAR HILL'}
# {'avg(ASSESSED_VALUE)': Decimal('415789.8429'), 'COMM_CODE': 'HUN', 'COMM_NAME': 'HUNTINGTON HILLS'}
# {'avg(ASSESSED_VALUE)': Decimal('519665.0212'), 'COMM_CODE': 'ING', 'COMM_NAME': 'INGLEWOOD'}
# {'avg(ASSESSED_VALUE)': Decimal('660565.0224'), 'COMM_CODE': 'KEL', 'COMM_NAME': 'KELVIN GROVE'}
# {'avg(ASSESSED_VALUE)': Decimal('540262.6939'), 'COMM_CODE': 'KIL', 'COMM_NAME': 'KILLARNEY/GLENGARRY'}
# {'avg(ASSESSED_VALUE)': Decimal('468300.3195'), 'COMM_CODE': 'KCA', 'COMM_NAME': 'KINCORA'}
# {'avg(ASSESSED_VALUE)': Decimal('487974.2063'), 'COMM_CODE': 'KIN', 'COMM_NAME': 'KINGSLAND'}
# {'avg(ASSESSED_VALUE)': Decimal('616574.5086'), 'COMM_CODE': 'LKB', 'COMM_NAME': 'LAKE BONAVISTA'}
# {'avg(ASSESSED_VALUE)': Decimal('727095.6354'), 'COMM_CODE': 'LKV', 'COMM_NAME': 'LAKEVIEW'}
# {'avg(ASSESSED_VALUE)': Decimal('380686.6507'), 'COMM_CODE': 'LEG', 'COMM_NAME': 'LEGACY'}
# {'avg(ASSESSED_VALUE)': Decimal('262950.2618'), 'COMM_CODE': 'LPK', 'COMM_NAME': 'LINCOLN PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('424935.9823'), 'COMM_CODE': 'LIV', 'COMM_NAME': 'LIVINGSTON'}
# {'avg(ASSESSED_VALUE)': Decimal('422248.5981'), 'COMM_CODE': 'LMR', 'COMM_NAME': 'LOWER MOUNT ROYAL'}
# {'avg(ASSESSED_VALUE)': Decimal('425866.0991'), 'COMM_CODE': 'MAC', 'COMM_NAME': 'MACEWAN'}
# {'avg(ASSESSED_VALUE)': Decimal('504982.3446'), 'COMM_CODE': 'MAH', 'COMM_NAME': 'MAHOGANY'}
# {'avg(ASSESSED_VALUE)': Decimal('547923.6111'), 'COMM_CODE': 'MAN', 'COMM_NAME': 'MANCHESTER'}
# {'avg(ASSESSED_VALUE)': Decimal('528430.5136'), 'COMM_CODE': 'MPL', 'COMM_NAME': 'MAPLE RIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('311795.1965'), 'COMM_CODE': 'MRL', 'COMM_NAME': 'MARLBOROUGH'}
# {'avg(ASSESSED_VALUE)': Decimal('301841.1876'), 'COMM_CODE': 'MPK', 'COMM_NAME': 'MARLBOROUGH PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('353093.3148'), 'COMM_CODE': 'MRT', 'COMM_NAME': 'MARTINDALE'}
# {'avg(ASSESSED_VALUE)': Decimal('1215157.8947'), 'COMM_CODE': 'MAF', 'COMM_NAME': 'MAYFAIR'}
# {'avg(ASSESSED_VALUE)': Decimal('430389.3499'), 'COMM_CODE': 'MAL', 'COMM_NAME': 'MAYLAND HEIGHTS'}
# {'avg(ASSESSED_VALUE)': Decimal('519369.0878'), 'COMM_CODE': 'MCK', 'COMM_NAME': 'MCKENZIE LAKE'}
# {'avg(ASSESSED_VALUE)': Decimal('371146.1916'), 'COMM_CODE': 'MCT', 'COMM_NAME': 'MCKENZIE TOWNE'}
# {'avg(ASSESSED_VALUE)': Decimal('685828.4314'), 'COMM_CODE': 'MEA', 'COMM_NAME': 'MEADOWLARK PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('475683.6506'), 'COMM_CODE': 'MID', 'COMM_NAME': 'MIDNAPORE'}
# {'avg(ASSESSED_VALUE)': Decimal('356367.5214'), 'COMM_CODE': 'MLR', 'COMM_NAME': 'MILLRISE'}
# {'avg(ASSESSED_VALUE)': Decimal('648989.7094'), 'COMM_CODE': 'MIS', 'COMM_NAME': 'MISSION'}
# {'avg(ASSESSED_VALUE)': Decimal('400021.6390'), 'COMM_CODE': 'MOR', 'COMM_NAME': 'MONTEREY PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('498812.1990'), 'COMM_CODE': 'MON', 'COMM_NAME': 'MONTGOMERY'}
# {'avg(ASSESSED_VALUE)': Decimal('643327.9689'), 'COMM_CODE': 'MOP', 'COMM_NAME': 'MOUNT PLEASANT'}
# {'avg(ASSESSED_VALUE)': Decimal('408946.1709'), 'COMM_CODE': 'NEB', 'COMM_NAME': 'NEW BRIGHTON'}
# {'avg(ASSESSED_VALUE)': Decimal('467432.2724'), 'COMM_CODE': 'NOL', 'COMM_NAME': 'NOLAN HILL'}
# {'avg(ASSESSED_VALUE)': Decimal('727173.8544'), 'COMM_CODE': 'NGM', 'COMM_NAME': 'NORTH GLENMORE PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('511516.0256'), 'COMM_CODE': 'NHV', 'COMM_NAME': 'NORTH HAVEN'}
# {'avg(ASSESSED_VALUE)': Decimal('511112.9032'), 'COMM_CODE': 'NHU', 'COMM_NAME': 'NORTH HAVEN UPPER'}
# {'avg(ASSESSED_VALUE)': Decimal('491152.6549'), 'COMM_CODE': 'OAK', 'COMM_NAME': 'OAKRIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('394827.6014'), 'COMM_CODE': 'OGD', 'COMM_NAME': 'OGDEN'}
# {'avg(ASSESSED_VALUE)': Decimal('503581.7972'), 'COMM_CODE': 'PAL', 'COMM_NAME': 'PALLISER'}
# {'avg(ASSESSED_VALUE)': Decimal('456927.6236'), 'COMM_CODE': 'PAN', 'COMM_NAME': 'PANORAMA HILLS'}
# {'avg(ASSESSED_VALUE)': Decimal('822666.2050'), 'COMM_CODE': 'PKD', 'COMM_NAME': 'PARKDALE'}
# {'avg(ASSESSED_VALUE)': Decimal('771295.4545'), 'COMM_CODE': 'PKH', 'COMM_NAME': 'PARKHILL/STANLEY PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('572984.5277'), 'COMM_CODE': 'PKL', 'COMM_NAME': 'PARKLAND'}
# {'avg(ASSESSED_VALUE)': Decimal('545256.3939'), 'COMM_CODE': 'PAT', 'COMM_NAME': 'PATTERSON'}
# {'avg(ASSESSED_VALUE)': Decimal('270969.8276'), 'COMM_CODE': 'PEN', 'COMM_NAME': 'PENBROOKE MEADOWS'}
# {'avg(ASSESSED_VALUE)': Decimal('349265.3654'), 'COMM_CODE': 'PIN', 'COMM_NAME': 'PINERIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('361953.5513'), 'COMM_CODE': 'POI', 'COMM_NAME': 'POINT MCKAY'}
# {'avg(ASSESSED_VALUE)': Decimal('1195596.9697'), 'COMM_CODE': 'PUM', 'COMM_NAME': 'PUMP HILL'}
# {'avg(ASSESSED_VALUE)': Decimal('355553.8793'), 'COMM_CODE': 'QLD', 'COMM_NAME': 'QUEENSLAND'}
# {'avg(ASSESSED_VALUE)': Decimal('626976.8519'), 'COMM_CODE': 'RAM', 'COMM_NAME': 'RAMSAY'}
# {'avg(ASSESSED_VALUE)': Decimal('372422.0355'), 'COMM_CODE': 'RAN', 'COMM_NAME': 'RANCHLANDS'}
# {'avg(ASSESSED_VALUE)': Decimal('340468.3544'), 'COMM_CODE': 'RED', 'COMM_NAME': 'RED CARPET/MOUNTVIEW MOBILE PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('418677.6398'), 'COMM_CODE': 'RSN', 'COMM_NAME': 'REDSTONE'}
# {'avg(ASSESSED_VALUE)': Decimal('459166.6667'), 'COMM_CODE': 'REN', 'COMM_NAME': 'RENFREW'}
# {'avg(ASSESSED_VALUE)': Decimal('1160085.7143'), 'COMM_CODE': '01F', 'COMM_NAME': 'RESIDUAL WARD 1 - SUB AREA 1F'}
# {'avg(ASSESSED_VALUE)': Decimal('885264.7059'), 'COMM_CODE': '10C', 'COMM_NAME': 'RESIDUAL WARD 10 - SUB AREA 10C'}
# {'avg(ASSESSED_VALUE)': Decimal('299145.8333'), 'COMM_CODE': '12A', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12A'}
# {'avg(ASSESSED_VALUE)': Decimal('1352125.0000'), 'COMM_CODE': '12C', 'COMM_NAME': 'RESIDUAL WARD 12 - SUB AREA 12C'}
# {'avg(ASSESSED_VALUE)': Decimal('677043.4726'), 'COMM_CODE': 'RIC', 'COMM_NAME': 'RICHMOND'}
# {'avg(ASSESSED_VALUE)': Decimal('744275.0000'), 'COMM_CODE': 'RID', 'COMM_NAME': 'RIDEAU PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('420165.8915'), 'COMM_CODE': 'RIV', 'COMM_NAME': 'RIVERBEND'}
# {'avg(ASSESSED_VALUE)': Decimal('471417.2662'), 'COMM_CODE': 'ROC', 'COMM_NAME': 'ROCKY RIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('1198238.2075'), 'COMM_CODE': 'RDL', 'COMM_NAME': 'ROSEDALE'}
# {'avg(ASSESSED_VALUE)': Decimal('699344.5183'), 'COMM_CODE': 'RMT', 'COMM_NAME': 'ROSEMONT'}
# {'avg(ASSESSED_VALUE)': Decimal('618643.8547'), 'COMM_CODE': 'RCK', 'COMM_NAME': 'ROSSCARROCK'}
# {'avg(ASSESSED_VALUE)': Decimal('1389112.0690'), 'COMM_CODE': 'ROX', 'COMM_NAME': 'ROXBORO'}
# {'avg(ASSESSED_VALUE)': Decimal('490748.4812'), 'COMM_CODE': 'ROY', 'COMM_NAME': 'ROYAL OAK'}
# {'avg(ASSESSED_VALUE)': Decimal('315098.9283'), 'COMM_CODE': 'RUN', 'COMM_NAME': 'RUNDLE'}
# {'avg(ASSESSED_VALUE)': Decimal('458589.4040'), 'COMM_CODE': 'RUT', 'COMM_NAME': 'RUTLAND PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('394291.8871'), 'COMM_CODE': 'SAD', 'COMM_NAME': 'SADDLE RIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('436882.8187'), 'COMM_CODE': 'SGH', 'COMM_NAME': 'SAGE HILL'}
# {'avg(ASSESSED_VALUE)': Decimal('418227.8481'), 'COMM_CODE': 'SAN', 'COMM_NAME': 'SANDSTONE VALLEY'}
# {'avg(ASSESSED_VALUE)': Decimal('1066390.6250'), 'COMM_CODE': 'SCA', 'COMM_NAME': 'SCARBORO'}
# {'avg(ASSESSED_VALUE)': Decimal('996114.2857'), 'COMM_CODE': 'SSW', 'COMM_NAME': 'SCARBORO/SUNALTA WEST'}
# {'avg(ASSESSED_VALUE)': Decimal('553195.5970'), 'COMM_CODE': 'SCE', 'COMM_NAME': 'SCENIC ACRES'}
# {'avg(ASSESSED_VALUE)': Decimal('688829.7414'), 'COMM_CODE': 'SET', 'COMM_NAME': 'SETON'}
# {'avg(ASSESSED_VALUE)': Decimal('672767.7291'), 'COMM_CODE': 'SHG', 'COMM_NAME': 'SHAGANAPPI'}
# {'avg(ASSESSED_VALUE)': Decimal('561072.1311'), 'COMM_CODE': 'SHS', 'COMM_NAME': 'SHAWNEE SLOPES'}
# {'avg(ASSESSED_VALUE)': Decimal('391093.3711'), 'COMM_CODE': 'SHN', 'COMM_NAME': 'SHAWNESSY'}
# {'avg(ASSESSED_VALUE)': Decimal('466711.5165'), 'COMM_CODE': 'SHW', 'COMM_NAME': 'SHERWOOD'}
# {'avg(ASSESSED_VALUE)': Decimal('529510.2625'), 'COMM_CODE': 'SIG', 'COMM_NAME': 'SIGNAL HILL'}
# {'avg(ASSESSED_VALUE)': Decimal('466943.3517'), 'COMM_CODE': 'SIL', 'COMM_NAME': 'SILVER SPRINGS'}
# {'avg(ASSESSED_VALUE)': Decimal('476458.4139'), 'COMM_CODE': 'SVO', 'COMM_NAME': 'SILVERADO'}
# {'avg(ASSESSED_VALUE)': Decimal('387040.7629'), 'COMM_CODE': 'SKR', 'COMM_NAME': 'SKYVIEW RANCH'}
# {'avg(ASSESSED_VALUE)': Decimal('373787.3913'), 'COMM_CODE': 'SOM', 'COMM_NAME': 'SOMERSET'}
# {'avg(ASSESSED_VALUE)': Decimal('562613.2597'), 'COMM_CODE': 'SOC', 'COMM_NAME': 'SOUTH CALGARY'}
# {'avg(ASSESSED_VALUE)': Decimal('395379.3860'), 'COMM_CODE': 'SOV', 'COMM_NAME': 'SOUTHVIEW'}
# {'avg(ASSESSED_VALUE)': Decimal('384777.8429'), 'COMM_CODE': 'SOW', 'COMM_NAME': 'SOUTHWOOD'}
# {'avg(ASSESSED_VALUE)': Decimal('796262.7058'), 'COMM_CODE': 'SPH', 'COMM_NAME': 'SPRINGBANK HILL'}
# {'avg(ASSESSED_VALUE)': Decimal('500139.0169'), 'COMM_CODE': 'SPR', 'COMM_NAME': 'SPRUCE CLIFF'}
# {'avg(ASSESSED_VALUE)': Decimal('942688.4058'), 'COMM_CODE': 'STA', 'COMM_NAME': 'ST. ANDREWS HEIGHTS'}
# {'avg(ASSESSED_VALUE)': Decimal('611189.7321'), 'COMM_CODE': 'STR', 'COMM_NAME': 'STRATHCONA PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('407976.2808'), 'COMM_CODE': 'SNA', 'COMM_NAME': 'SUNALTA'}
# {'avg(ASSESSED_VALUE)': Decimal('506794.4265'), 'COMM_CODE': 'SDC', 'COMM_NAME': 'SUNDANCE'}
# {'avg(ASSESSED_VALUE)': Decimal('503202.0202'), 'COMM_CODE': 'SSD', 'COMM_NAME': 'SUNNYSIDE'}
# {'avg(ASSESSED_VALUE)': Decimal('370161.3001'), 'COMM_CODE': 'TAR', 'COMM_NAME': 'TARADALE'}
# {'avg(ASSESSED_VALUE)': Decimal('319391.9330'), 'COMM_CODE': 'TEM', 'COMM_NAME': 'TEMPLE'}
# {'avg(ASSESSED_VALUE)': Decimal('426322.3327'), 'COMM_CODE': 'THO', 'COMM_NAME': 'THORNCLIFFE'}
# {'avg(ASSESSED_VALUE)': Decimal('518914.9751'), 'COMM_CODE': 'TUS', 'COMM_NAME': 'TUSCANY'}
# {'avg(ASSESSED_VALUE)': Decimal('518744.3182'), 'COMM_CODE': 'TUX', 'COMM_NAME': 'TUXEDO PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('7991047.6190'), 'COMM_CODE': 'UND', 'COMM_NAME': 'UNIVERSITY DISTRICT'}
# {'avg(ASSESSED_VALUE)': Decimal('1427633.9713'), 'COMM_CODE': 'UNI', 'COMM_NAME': 'UNIVERSITY HEIGHTS'}
# {'avg(ASSESSED_VALUE)': Decimal('1837640.1734'), 'COMM_CODE': 'UMR', 'COMM_NAME': 'UPPER MOUNT ROYAL'}
# {'avg(ASSESSED_VALUE)': Decimal('602883.6898'), 'COMM_CODE': 'VAL', 'COMM_NAME': 'VALLEY RIDGE'}
# {'avg(ASSESSED_VALUE)': Decimal('604167.4324'), 'COMM_CODE': 'VAR', 'COMM_NAME': 'VARSITY'}
# {'avg(ASSESSED_VALUE)': Decimal('394230.1255'), 'COMM_CODE': 'VIS', 'COMM_NAME': 'VISTA HEIGHTS'}
# {'avg(ASSESSED_VALUE)': Decimal('448555.7308'), 'COMM_CODE': 'WAL', 'COMM_NAME': 'WALDEN'}
# {'avg(ASSESSED_VALUE)': Decimal('792577.9773'), 'COMM_CODE': 'WHL', 'COMM_NAME': 'WEST HILLHURST'}
# {'avg(ASSESSED_VALUE)': Decimal('746829.9224'), 'COMM_CODE': 'WSP', 'COMM_NAME': 'WEST SPRINGS'}
# {'avg(ASSESSED_VALUE)': Decimal('537492.3246'), 'COMM_CODE': 'WGT', 'COMM_NAME': 'WESTGATE'}
# {'avg(ASSESSED_VALUE)': Decimal('328303.2544'), 'COMM_CODE': 'WHI', 'COMM_NAME': 'WHITEHORN'}
# {'avg(ASSESSED_VALUE)': Decimal('763623.6413'), 'COMM_CODE': 'WLD', 'COMM_NAME': 'WILDWOOD'}
# {'avg(ASSESSED_VALUE)': Decimal('574079.5455'), 'COMM_CODE': 'WIL', 'COMM_NAME': 'WILLOW PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('491677.1596'), 'COMM_CODE': 'WND', 'COMM_NAME': 'WINDSOR PARK'}
# {'avg(ASSESSED_VALUE)': Decimal('531639.2405'), 'COMM_CODE': 'WIN', 'COMM_NAME': 'WINSTON HEIGHTS/MOUNTVIEW'}
# {'avg(ASSESSED_VALUE)': Decimal('464879.7753'), 'COMM_CODE': 'WBN', 'COMM_NAME': 'WOODBINE'}
# {'avg(ASSESSED_VALUE)': Decimal('481322.8247'), 'COMM_CODE': 'WOO', 'COMM_NAME': 'WOODLANDS'}
# True

# %% [markdown]
# Getting the average property assessment values for each community allows us to be able to easily visualize property assessment values between our communities. It allows us to find which communities on average are lower end communities vs higher end communities. This helps us for our final project in seeing if there are relationships between certain communities and their crime counts and types. This is also the same case for when we compare it to demographics and see if there is a relationship between certain demographics and average property assessment values of communities.

# %% [markdown]
# ## Query 5

# %%
#Find the top 10 communities to look into based on property counts if you are interested in buying a home within a certain price range. Each price range increment is 250,000

#make a list of the upper range of the price range
prop_upper_lim = [350000, 600000, 850000, 1100000, 1350000]

read_cursor = myconnection.cursor(buffered=True, dictionary=True)

query_string = ("SELECT count(ASSESSED_VALUE), COMM_CODE, COMM_NAME FROM property_data WHERE ASSESSED_VALUE BETWEEN %s-250000 AND %s GROUP BY COMM_NAME ORDER BY count(ASSESSED_VALUE) DESC LIMIT 10;")

#loop through our price ranges and insert them into the %s placeholders
for prop_range in prop_upper_lim: 
    print("Top 10 Communities to look into if you are buying a home in the price range:", prop_range - 250000, "-", prop_range)
    read_cursor.execute(query_string, (prop_range,prop_range,))
    for (prop_value) in read_cursor:
        print(prop_value)
        
read_cursor.close()
# Out:
# Top 10 Communities to look into if you are buying a home in the price range: 100000 - 350000
# {'count(ASSESSED_VALUE)': 3177, 'COMM_CODE': 'BLN', 'COMM_NAME': 'BELTLINE'}
# {'count(ASSESSED_VALUE)': 1436, 'COMM_CODE': 'DOV', 'COMM_NAME': 'DOVER'}
# {'count(ASSESSED_VALUE)': 1429, 'COMM_CODE': 'MCT', 'COMM_NAME': 'MCKENZIE TOWNE'}
# {'count(ASSESSED_VALUE)': 1027, 'COMM_CODE': 'FAL', 'COMM_NAME': 'FALCONRIDGE'}
# {'count(ASSESSED_VALUE)': 1008, 'COMM_CODE': 'PEN', 'COMM_NAME': 'PENBROOKE MEADOWS'}
# {'count(ASSESSED_VALUE)': 954, 'COMM_CODE': 'PAN', 'COMM_NAME': 'PANORAMA HILLS'}
# {'count(ASSESSED_VALUE)': 875, 'COMM_CODE': 'PIN', 'COMM_NAME': 'PINERIDGE'}
# {'count(ASSESSED_VALUE)': 875, 'COMM_CODE': 'MRL', 'COMM_NAME': 'MARLBOROUGH'}
# {'count(ASSESSED_VALUE)': 852, 'COMM_CODE': 'MPK', 'COMM_NAME': 'MARLBOROUGH PARK'}
# {'count(ASSESSED_VALUE)': 828, 'COMM_CODE': 'MRT', 'COMM_NAME': 'MARTINDALE'}
# Top 10 Communities to look into if you are buying a home in the price range: 350000 - 600000
# {'count(ASSESSED_VALUE)': 1873, 'COMM_CODE': 'PAN', 'COMM_NAME': 'PANORAMA HILLS'}
# {'count(ASSESSED_VALUE)': 1721, 'COMM_CODE': 'EVE', 'COMM_NAME': 'EVERGREEN'}
# {'count(ASSESSED_VALUE)': 1700, 'COMM_CODE': 'TUS', 'COMM_NAME': 'TUSCANY'}
# {'count(ASSESSED_VALUE)': 1577, 'COMM_CODE': 'EVN', 'COMM_NAME': 'EVANSTON'}
# {'count(ASSESSED_VALUE)': 1564, 'COMM_CODE': 'CRA', 'COMM_NAME': 'CRANSTON'}
# {'count(ASSESSED_VALUE)': 1540, 'COMM_CODE': 'COV', 'COMM_NAME': 'COVENTRY HILLS'}
# {'count(ASSESSED_VALUE)': 1517, 'COMM_CODE': 'DDG', 'COMM_NAME': 'DOUGLASDALE/GLEN'}
# {'count(ASSESSED_VALUE)': 1352, 'COMM_CODE': 'SAD', 'COMM_NAME': 'SADDLE RIDGE'}
# {'count(ASSESSED_VALUE)': 1275, 'COMM_CODE': 'NEB', 'COMM_NAME': 'NEW BRIGHTON'}
# {'count(ASSESSED_VALUE)': 1272, 'COMM_CODE': 'MCT', 'COMM_NAME': 'MCKENZIE TOWNE'}
# Top 10 Communities to look into if you are buying a home in the price range: 600000 - 850000
# {'count(ASSESSED_VALUE)': 723, 'COMM_CODE': 'SIG', 'COMM_NAME': 'SIGNAL HILL'}
# {'count(ASSESSED_VALUE)': 711, 'COMM_CODE': 'EDG', 'COMM_NAME': 'EDGEMONT'}
# {'count(ASSESSED_VALUE)': 591, 'COMM_CODE': 'HAM', 'COMM_NAME': 'HAMPTONS'}
# {'count(ASSESSED_VALUE)': 497, 'COMM_CODE': 'TUS', 'COMM_NAME': 'TUSCANY'}
# {'count(ASSESSED_VALUE)': 477, 'COMM_CODE': 'WSP', 'COMM_NAME': 'WEST SPRINGS'}
# {'count(ASSESSED_VALUE)': 469, 'COMM_CODE': 'KIL', 'COMM_NAME': 'KILLARNEY/GLENGARRY'}
# {'count(ASSESSED_VALUE)': 468, 'COMM_CODE': 'SPH', 'COMM_NAME': 'SPRINGBANK HILL'}
# {'count(ASSESSED_VALUE)': 453, 'COMM_CODE': 'PAN', 'COMM_NAME': 'PANORAMA HILLS'}
# {'count(ASSESSED_VALUE)': 446, 'COMM_CODE': 'LKB', 'COMM_NAME': 'LAKE BONAVISTA'}
# {'count(ASSESSED_VALUE)': 438, 'COMM_CODE': 'WHL', 'COMM_NAME': 'WEST HILLHURST'}
# Top 10 Communities to look into if you are buying a home in the price range: 850000 - 1100000
# {'count(ASSESSED_VALUE)': 269, 'COMM_CODE': 'ASP', 'COMM_NAME': 'ASPEN WOODS'}
# {'count(ASSESSED_VALUE)': 263, 'COMM_CODE': 'ALT', 'COMM_NAME': 'ALTADORE'}
# {'count(ASSESSED_VALUE)': 256, 'COMM_CODE': 'WSP', 'COMM_NAME': 'WEST SPRINGS'}
# {'count(ASSESSED_VALUE)': 174, 'COMM_CODE': 'VAR', 'COMM_NAME': 'VARSITY'}
# {'count(ASSESSED_VALUE)': 158, 'COMM_CODE': 'SPH', 'COMM_NAME': 'SPRINGBANK HILL'}
# {'count(ASSESSED_VALUE)': 152, 'COMM_CODE': 'WHL', 'COMM_NAME': 'WEST HILLHURST'}
# {'count(ASSESSED_VALUE)': 139, 'COMM_CODE': 'DIS', 'COMM_NAME': 'DISCOVERY RIDGE'}
# {'count(ASSESSED_VALUE)': 119, 'COMM_CODE': 'HIL', 'COMM_NAME': 'HILLHURST'}
# {'count(ASSESSED_VALUE)': 110, 'COMM_CODE': 'SIG', 'COMM_NAME': 'SIGNAL HILL'}
# {'count(ASSESSED_VALUE)': 99, 'COMM_CODE': 'EPK', 'COMM_NAME': 'ELBOW PARK'}
# Top 10 Communities to look into if you are buying a home in the price range: 1100000 - 1350000
# {'count(ASSESSED_VALUE)': 168, 'COMM_CODE': 'ASP', 'COMM_NAME': 'ASPEN WOODS'}
# {'count(ASSESSED_VALUE)': 100, 'COMM_CODE': 'EPK', 'COMM_NAME': 'ELBOW PARK'}
# {'count(ASSESSED_VALUE)': 97, 'COMM_CODE': 'SPH', 'COMM_NAME': 'SPRINGBANK HILL'}
# {'count(ASSESSED_VALUE)': 85, 'COMM_CODE': 'WSP', 'COMM_NAME': 'WEST SPRINGS'}
# {'count(ASSESSED_VALUE)': 75, 'COMM_CODE': 'ALT', 'COMM_NAME': 'ALTADORE'}
# {'count(ASSESSED_VALUE)': 73, 'COMM_CODE': 'WHL', 'COMM_NAME': 'WEST HILLHURST'}
# {'count(ASSESSED_VALUE)': 70, 'COMM_CODE': 'HIL', 'COMM_NAME': 'HILLHURST'}
# {'count(ASSESSED_VALUE)': 68, 'COMM_CODE': 'CRA', 'COMM_NAME': 'CRANSTON'}
# {'count(ASSESSED_VALUE)': 45, 'COMM_CODE': 'MCK', 'COMM_NAME': 'MCKENZIE LAKE'}
# {'count(ASSESSED_VALUE)': 41, 'COMM_CODE': 'UMR', 'COMM_NAME': 'UPPER MOUNT ROYAL'}
# True

# %% [markdown]
# One point of our project was to gain insight on communities that people may be interested in when buying a new home, whether it be for the first time or if you simply want to live in a higher end property. Finding the top 10 communities that have the highest count of properties that is within a specific price range gives us this very insight. Furthermore we can use this information along with our other datasets to help expand on our guiding questions (Such as when we look at relationships between age demographics and property assessment values in communities).
#
# We chose to go up by incremements of 250,000 for each property assessment value range.

# %% [markdown]
# ## Query 6

# %%
#Get average sq. footage of properties per each community below the chosen sq. footage value threshold

read_cursor = myconnection.cursor(buffered=True, dictionary=True)

query_string = ("SELECT avg(LAND_SIZE_SF), COMM_NAME FROM property_data WHERE ASSESSED_VALUE > 100000 AND LAND_SIZE_SF < 15000 GROUP BY COMM_NAME HAVING count(COMM_CODE) > 10;")

read_cursor.execute(query_string)

for (prop_value) in read_cursor:
    print(prop_value)
    
read_cursor.close()
# Out:
# {'avg(LAND_SIZE_SF)': 4099.422316384181, 'COMM_NAME': 'ABBEYDALE'}
# {'avg(LAND_SIZE_SF)': 5727.267837541163, 'COMM_NAME': 'ACADIA'}
# {'avg(LAND_SIZE_SF)': 5500.396226415094, 'COMM_NAME': 'ALBERT PARK/RADISSON HEIGHTS'}
# {'avg(LAND_SIZE_SF)': 4892.798117154812, 'COMM_NAME': 'ALTADORE'}
# {'avg(LAND_SIZE_SF)': 4184.833333333333, 'COMM_NAME': 'APPLEWOOD PARK'}
# {'avg(LAND_SIZE_SF)': 4882.549158547387, 'COMM_NAME': 'ARBOUR LAKE'}
# {'avg(LAND_SIZE_SF)': 5608.866537717601, 'COMM_NAME': 'ASPEN WOODS'}
# {'avg(LAND_SIZE_SF)': 4365.851798561151, 'COMM_NAME': 'AUBURN BAY'}
# {'avg(LAND_SIZE_SF)': 5827.481707317073, 'COMM_NAME': 'BANFF TRAIL'}
# {'avg(LAND_SIZE_SF)': 7486.755520504732, 'COMM_NAME': 'BANKVIEW'}
# {'avg(LAND_SIZE_SF)': 10119.556962025317, 'COMM_NAME': 'BAYVIEW'}
# {'avg(LAND_SIZE_SF)': 4515.905109489051, 'COMM_NAME': 'BEDDINGTON HEIGHTS'}
# {'avg(LAND_SIZE_SF)': 12198.415384615384, 'COMM_NAME': 'BEL-AIRE'}
# {'avg(LAND_SIZE_SF)': 3453.4603174603176, 'COMM_NAME': 'BELMONT'}
# {'avg(LAND_SIZE_SF)': 7722.231041814316, 'COMM_NAME': 'BELTLINE'}
# {'avg(LAND_SIZE_SF)': 5689.262295081967, 'COMM_NAME': 'BONAVISTA DOWNS'}
# {'avg(LAND_SIZE_SF)': 6248.739736638265, 'COMM_NAME': 'BOWNESS'}
# {'avg(LAND_SIZE_SF)': 6432.941499085923, 'COMM_NAME': 'BRAESIDE'}
# {'avg(LAND_SIZE_SF)': 5294.228695652174, 'COMM_NAME': 'BRENTWOOD'}
# {'avg(LAND_SIZE_SF)': 4908.744402985075, 'COMM_NAME': 'BRIDGELAND/RIVERSIDE'}
# {'avg(LAND_SIZE_SF)': 3911.71953125, 'COMM_NAME': 'BRIDLEWOOD'}
# {'avg(LAND_SIZE_SF)': 10147.46956521739, 'COMM_NAME': 'BRITANNIA'}
# {'avg(LAND_SIZE_SF)': 6002.482758620689, 'COMM_NAME': 'CAMBRIAN HEIGHTS'}
# {'avg(LAND_SIZE_SF)': 6703.499396863691, 'COMM_NAME': 'CANYON MEADOWS'}
# {'avg(LAND_SIZE_SF)': 4682.808695652174, 'COMM_NAME': 'CAPITOL HILL'}
# {'avg(LAND_SIZE_SF)': 3254.3678571428572, 'COMM_NAME': 'CARRINGTON'}
# {'avg(LAND_SIZE_SF)': 4513.262422360249, 'COMM_NAME': 'CASTLERIDGE'}
# {'avg(LAND_SIZE_SF)': 4603.389513108615, 'COMM_NAME': 'CEDARBRAE'}
# {'avg(LAND_SIZE_SF)': 4692.190860215053, 'COMM_NAME': 'CHAPARRAL'}
# {'avg(LAND_SIZE_SF)': 6048.394990366089, 'COMM_NAME': 'CHARLESWOOD'}
# {'avg(LAND_SIZE_SF)': 4769.570212765958, 'COMM_NAME': 'CHINATOWN'}
# {'avg(LAND_SIZE_SF)': 7092.994736842105, 'COMM_NAME': 'CHINOOK PARK'}
# {'avg(LAND_SIZE_SF)': 6511.99537037037, 'COMM_NAME': 'CHRISTIE PARK'}
# {'avg(LAND_SIZE_SF)': 4358.450076804916, 'COMM_NAME': 'CITADEL'}
# {'avg(LAND_SIZE_SF)': 2658.295612009238, 'COMM_NAME': 'CITYSCAPE'}
# {'avg(LAND_SIZE_SF)': 6367.677419354839, 'COMM_NAME': 'CLIFF BUNGALOW'}
# {'avg(LAND_SIZE_SF)': 5912.1943462897525, 'COMM_NAME': 'COACH HILL'}
# {'avg(LAND_SIZE_SF)': 6796.585526315789, 'COMM_NAME': 'COLLINGWOOD'}
# {'avg(LAND_SIZE_SF)': 3452.3110539845757, 'COMM_NAME': 'COPPERFIELD'}
# {'avg(LAND_SIZE_SF)': 5107.376838235294, 'COMM_NAME': 'CORAL SPRINGS'}
# {'avg(LAND_SIZE_SF)': 3309.9741550695826, 'COMM_NAME': 'CORNERSTONE'}
# {'avg(LAND_SIZE_SF)': 4764.111111111111, 'COMM_NAME': 'COUGAR RIDGE'}
# {'avg(LAND_SIZE_SF)': 3963.6680412371134, 'COMM_NAME': 'COUNTRY HILLS'}
# {'avg(LAND_SIZE_SF)': 1482.2944785276075, 'COMM_NAME': 'COUNTRY HILLS VILLAGE'}
# {'avg(LAND_SIZE_SF)': 3997.693036475604, 'COMM_NAME': 'COVENTRY HILLS'}
# {'avg(LAND_SIZE_SF)': 4703.8650729335495, 'COMM_NAME': 'CRANSTON'}
# {'avg(LAND_SIZE_SF)': 6766.469230769231, 'COMM_NAME': 'CRESCENT HEIGHTS'}
# {'avg(LAND_SIZE_SF)': 5326.637992831541, 'COMM_NAME': 'CRESTMONT'}
# {'avg(LAND_SIZE_SF)': 3865.040404040404, 'COMM_NAME': 'CURRIE BARRACKS'}
# {'avg(LAND_SIZE_SF)': 6685.919216646267, 'COMM_NAME': 'DALHOUSIE'}
# {'avg(LAND_SIZE_SF)': 5331.1057692307695, 'COMM_NAME': 'DEER RIDGE'}
# {'avg(LAND_SIZE_SF)': 5914.116314199396, 'COMM_NAME': 'DEER RUN'}
# {'avg(LAND_SIZE_SF)': 6895.445544554455, 'COMM_NAME': 'DIAMOND COVE'}
# {'avg(LAND_SIZE_SF)': 6314.52, 'COMM_NAME': 'DISCOVERY RIDGE'}
# {'avg(LAND_SIZE_SF)': 5423.879951249238, 'COMM_NAME': 'DOUGLASDALE/GLEN'}
# {'avg(LAND_SIZE_SF)': 4337.219869706841, 'COMM_NAME': 'DOVER'}
# {'avg(LAND_SIZE_SF)': 7204.057692307692, 'COMM_NAME': 'DOWNTOWN COMMERCIAL CORE'}
# {'avg(LAND_SIZE_SF)': 6082.040983606557, 'COMM_NAME': 'DOWNTOWN EAST VILLAGE'}
# {'avg(LAND_SIZE_SF)': 2343.6488095238096, 'COMM_NAME': 'DOWNTOWN WEST END'}
# {'avg(LAND_SIZE_SF)': 13585.8125, 'COMM_NAME': 'EAGLE RIDGE'}
# {'avg(LAND_SIZE_SF)': 13574.333333333334, 'COMM_NAME': 'EAU CLAIRE'}
# {'avg(LAND_SIZE_SF)': 6165.1661184210525, 'COMM_NAME': 'EDGEMONT'}
# {'avg(LAND_SIZE_SF)': 6882.863539445629, 'COMM_NAME': 'ELBOW PARK'}
# {'avg(LAND_SIZE_SF)': 6687.1682692307695, 'COMM_NAME': 'ELBOYA'}
# {'avg(LAND_SIZE_SF)': 3739.185873605948, 'COMM_NAME': 'ERIN WOODS'}
# {'avg(LAND_SIZE_SF)': 3777.1946902654868, 'COMM_NAME': 'ERLTON'}
# {'avg(LAND_SIZE_SF)': 4132.398058252427, 'COMM_NAME': 'EVANSTON'}
# {'avg(LAND_SIZE_SF)': 4392.577173030057, 'COMM_NAME': 'EVERGREEN'}
# {'avg(LAND_SIZE_SF)': 5640.369834710744, 'COMM_NAME': 'FAIRVIEW'}
# {'avg(LAND_SIZE_SF)': 4148.400225479143, 'COMM_NAME': 'FALCONRIDGE'}
# {'avg(LAND_SIZE_SF)': 5082.569131832797, 'COMM_NAME': 'FOREST HEIGHTS'}
# {'avg(LAND_SIZE_SF)': 6160.662420382166, 'COMM_NAME': 'FOREST LAWN'}
# {'avg(LAND_SIZE_SF)': 2152.326271186441, 'COMM_NAME': 'GARRISON GREEN'}
# {'avg(LAND_SIZE_SF)': 3776.022950819672, 'COMM_NAME': 'GARRISON WOODS'}
# {'avg(LAND_SIZE_SF)': 5896.008230452675, 'COMM_NAME': 'GLAMORGAN'}
# {'avg(LAND_SIZE_SF)': 5097.09963099631, 'COMM_NAME': 'GLENBROOK'}
# {'avg(LAND_SIZE_SF)': 6676.816, 'COMM_NAME': 'GLENDALE'}
# {'avg(LAND_SIZE_SF)': 5373.64406779661, 'COMM_NAME': 'GREENVIEW'}
# {'avg(LAND_SIZE_SF)': 5848.112554112554, 'COMM_NAME': 'HAMPTONS'}
# {'avg(LAND_SIZE_SF)': 4546.720464135021, 'COMM_NAME': 'HARVEST HILLS'}
# {'avg(LAND_SIZE_SF)': 5995.4090163934425, 'COMM_NAME': 'HAWKWOOD'}
# {'avg(LAND_SIZE_SF)': 6187.310541310541, 'COMM_NAME': 'HAYSBORO'}
# {'avg(LAND_SIZE_SF)': 4583.594766619519, 'COMM_NAME': 'HIDDEN VALLEY'}
# {'avg(LAND_SIZE_SF)': 5310.434523809524, 'COMM_NAME': 'HIGHLAND PARK'}
# {'avg(LAND_SIZE_SF)': 5753.959375, 'COMM_NAME': 'HIGHWOOD'}
# {'avg(LAND_SIZE_SF)': 4987.361001317523, 'COMM_NAME': 'HILLHURST'}
# {'avg(LAND_SIZE_SF)': 6939.674242424242, 'COMM_NAME': 'HOUNSFIELD HEIGHTS/BRIAR HILL'}
# {'avg(LAND_SIZE_SF)': 5883.08784676354, 'COMM_NAME': 'HUNTINGTON HILLS'}
# {'avg(LAND_SIZE_SF)': 4119.434156378601, 'COMM_NAME': 'INGLEWOOD'}
# {'avg(LAND_SIZE_SF)': 7754.695652173913, 'COMM_NAME': 'KELVIN GROVE'}
# {'avg(LAND_SIZE_SF)': 5221.5649717514125, 'COMM_NAME': 'KILLARNEY/GLENGARRY'}
# {'avg(LAND_SIZE_SF)': 4416.888198757764, 'COMM_NAME': 'KINCORA'}
# {'avg(LAND_SIZE_SF)': 6122.079096045198, 'COMM_NAME': 'KINGSLAND'}
# {'avg(LAND_SIZE_SF)': 6906.560421735604, 'COMM_NAME': 'LAKE BONAVISTA'}
# {'avg(LAND_SIZE_SF)': 6711.035087719299, 'COMM_NAME': 'LAKEVIEW'}
# {'avg(LAND_SIZE_SF)': 3582.040243902439, 'COMM_NAME': 'LEGACY'}
# {'avg(LAND_SIZE_SF)': 3603.044705882353, 'COMM_NAME': 'LIVINGSTON'}
# {'avg(LAND_SIZE_SF)': 8552.779264214047, 'COMM_NAME': 'LOWER MOUNT ROYAL'}
# {'avg(LAND_SIZE_SF)': 4825.145135566188, 'COMM_NAME': 'MACEWAN'}
# {'avg(LAND_SIZE_SF)': 3242.2513034410845, 'COMM_NAME': 'MAHOGANY'}
# {'avg(LAND_SIZE_SF)': 4478.0, 'COMM_NAME': 'MANCHESTER'}
# {'avg(LAND_SIZE_SF)': 6325.722054380664, 'COMM_NAME': 'MAPLE RIDGE'}
# {'avg(LAND_SIZE_SF)': 5237.827771797632, 'COMM_NAME': 'MARLBOROUGH'}
# {'avg(LAND_SIZE_SF)': 5223.906288532676, 'COMM_NAME': 'MARLBOROUGH PARK'}
# {'avg(LAND_SIZE_SF)': 3590.58495821727, 'COMM_NAME': 'MARTINDALE'}
# {'avg(LAND_SIZE_SF)': 10111.641509433963, 'COMM_NAME': 'MAYFAIR'}
# {'avg(LAND_SIZE_SF)': 5312.3125, 'COMM_NAME': 'MAYLAND HEIGHTS'}
# {'avg(LAND_SIZE_SF)': 5380.230681167716, 'COMM_NAME': 'MCKENZIE LAKE'}
# {'avg(LAND_SIZE_SF)': 4251.741413150147, 'COMM_NAME': 'MCKENZIE TOWNE'}
# {'avg(LAND_SIZE_SF)': 6559.774509803921, 'COMM_NAME': 'MEADOWLARK PARK'}
# {'avg(LAND_SIZE_SF)': 5107.773351648351, 'COMM_NAME': 'MIDNAPORE'}
# {'avg(LAND_SIZE_SF)': 4417.599502487562, 'COMM_NAME': 'MILLRISE'}
# {'avg(LAND_SIZE_SF)': 8920.19, 'COMM_NAME': 'MISSION'}
# {'avg(LAND_SIZE_SF)': 4415.229689067201, 'COMM_NAME': 'MONTEREY PARK'}
# {'avg(LAND_SIZE_SF)': 5060.039669421488, 'COMM_NAME': 'MONTGOMERY'}
# {'avg(LAND_SIZE_SF)': 4811.903415783275, 'COMM_NAME': 'MOUNT PLEASANT'}
# {'avg(LAND_SIZE_SF)': 3814.9156626506024, 'COMM_NAME': 'NEW BRIGHTON'}
# {'avg(LAND_SIZE_SF)': 3164.6112084063047, 'COMM_NAME': 'NOLAN HILL'}
# {'avg(LAND_SIZE_SF)': 6220.826558265582, 'COMM_NAME': 'NORTH GLENMORE PARK'}
# {'avg(LAND_SIZE_SF)': 5631.359589041096, 'COMM_NAME': 'NORTH HAVEN'}
# {'avg(LAND_SIZE_SF)': 6124.236559139785, 'COMM_NAME': 'NORTH HAVEN UPPER'}
# {'avg(LAND_SIZE_SF)': 7193.468115942029, 'COMM_NAME': 'OAKRIDGE'}
# {'avg(LAND_SIZE_SF)': 5029.3228962818, 'COMM_NAME': 'OGDEN'}
# {'avg(LAND_SIZE_SF)': 7115.55376344086, 'COMM_NAME': 'PALLISER'}
# {'avg(LAND_SIZE_SF)': 4257.320125130344, 'COMM_NAME': 'PANORAMA HILLS'}
# {'avg(LAND_SIZE_SF)': 5080.107255520505, 'COMM_NAME': 'PARKDALE'}
# {'avg(LAND_SIZE_SF)': 4674.568965517241, 'COMM_NAME': 'PARKHILL/STANLEY PARK'}
# {'avg(LAND_SIZE_SF)': 6941.6478102189785, 'COMM_NAME': 'PARKLAND'}
# {'avg(LAND_SIZE_SF)': 6782.4276315789475, 'COMM_NAME': 'PATTERSON'}
# {'avg(LAND_SIZE_SF)': 4658.160227272727, 'COMM_NAME': 'PENBROOKE MEADOWS'}
# {'avg(LAND_SIZE_SF)': 4850.2223393045315, 'COMM_NAME': 'PINERIDGE'}
# {'avg(LAND_SIZE_SF)': 8935.257352941177, 'COMM_NAME': 'PUMP HILL'}
# {'avg(LAND_SIZE_SF)': 5483.312839059675, 'COMM_NAME': 'QUEENSLAND'}
# {'avg(LAND_SIZE_SF)': 4409.514106583072, 'COMM_NAME': 'RAMSAY'}
# {'avg(LAND_SIZE_SF)': 5140.799489144317, 'COMM_NAME': 'RANCHLANDS'}
# {'avg(LAND_SIZE_SF)': 3310.263979193758, 'COMM_NAME': 'REDSTONE'}
# {'avg(LAND_SIZE_SF)': 6018.284738041002, 'COMM_NAME': 'RENFREW'}
# {'avg(LAND_SIZE_SF)': 4928.03156384505, 'COMM_NAME': 'RICHMOND'}
# {'avg(LAND_SIZE_SF)': 6773.677966101695, 'COMM_NAME': 'RIDEAU PARK'}
# {'avg(LAND_SIZE_SF)': 4694.300787401575, 'COMM_NAME': 'RIVERBEND'}
# {'avg(LAND_SIZE_SF)': 4631.838028169014, 'COMM_NAME': 'ROCKY RIDGE'}
# {'avg(LAND_SIZE_SF)': 5926.530805687204, 'COMM_NAME': 'ROSEDALE'}
# {'avg(LAND_SIZE_SF)': 6189.378048780488, 'COMM_NAME': 'ROSEMONT'}
# {'avg(LAND_SIZE_SF)': 5533.339031339031, 'COMM_NAME': 'ROSSCARROCK'}
# {'avg(LAND_SIZE_SF)': 6939.087719298245, 'COMM_NAME': 'ROXBORO'}
# {'avg(LAND_SIZE_SF)': 4732.8357191547375, 'COMM_NAME': 'ROYAL OAK'}
# {'avg(LAND_SIZE_SF)': 5284.927489177489, 'COMM_NAME': 'RUNDLE'}
# {'avg(LAND_SIZE_SF)': 6252.12676056338, 'COMM_NAME': 'RUTLAND PARK'}
# {'avg(LAND_SIZE_SF)': 3759.584239130435, 'COMM_NAME': 'SADDLE RIDGE'}
# {'avg(LAND_SIZE_SF)': 4719.6580952380955, 'COMM_NAME': 'SAGE HILL'}
# {'avg(LAND_SIZE_SF)': 4904.117647058823, 'COMM_NAME': 'SANDSTONE VALLEY'}
# {'avg(LAND_SIZE_SF)': 6860.204724409449, 'COMM_NAME': 'SCARBORO'}
# {'avg(LAND_SIZE_SF)': 7841.55223880597, 'COMM_NAME': 'SCARBORO/SUNALTA WEST'}
# {'avg(LAND_SIZE_SF)': 5863.544117647059, 'COMM_NAME': 'SCENIC ACRES'}
# {'avg(LAND_SIZE_SF)': 3989.9714285714285, 'COMM_NAME': 'SETON'}
# {'avg(LAND_SIZE_SF)': 5846.3877551020405, 'COMM_NAME': 'SHAGANAPPI'}
# {'avg(LAND_SIZE_SF)': 5884.375, 'COMM_NAME': 'SHAWNEE SLOPES'}
# {'avg(LAND_SIZE_SF)': 4716.637915543576, 'COMM_NAME': 'SHAWNESSY'}
# {'avg(LAND_SIZE_SF)': 4370.421746293246, 'COMM_NAME': 'SHERWOOD'}
# {'avg(LAND_SIZE_SF)': 5878.92934051144, 'COMM_NAME': 'SIGNAL HILL'}
# {'avg(LAND_SIZE_SF)': 6173.314453125, 'COMM_NAME': 'SILVER SPRINGS'}
# {'avg(LAND_SIZE_SF)': 4596.290456431535, 'COMM_NAME': 'SILVERADO'}
# {'avg(LAND_SIZE_SF)': 3430.975118483412, 'COMM_NAME': 'SKYVIEW RANCH'}
# {'avg(LAND_SIZE_SF)': 4522.161399548533, 'COMM_NAME': 'SOMERSET'}
# {'avg(LAND_SIZE_SF)': 5421.346416382253, 'COMM_NAME': 'SOUTH CALGARY'}
# {'avg(LAND_SIZE_SF)': 6184.651982378855, 'COMM_NAME': 'SOUTHVIEW'}
# {'avg(LAND_SIZE_SF)': 6019.484472049689, 'COMM_NAME': 'SOUTHWOOD'}
# {'avg(LAND_SIZE_SF)': 6563.035849056604, 'COMM_NAME': 'SPRINGBANK HILL'}
# {'avg(LAND_SIZE_SF)': 5849.067901234568, 'COMM_NAME': 'SPRUCE CLIFF'}
# {'avg(LAND_SIZE_SF)': 6991.166666666667, 'COMM_NAME': 'ST. ANDREWS HEIGHTS'}
# {'avg(LAND_SIZE_SF)': 5630.172839506173, 'COMM_NAME': 'STRATHCONA PARK'}
# {'avg(LAND_SIZE_SF)': 7833.014778325123, 'COMM_NAME': 'SUNALTA'}
# {'avg(LAND_SIZE_SF)': 5347.876923076923, 'COMM_NAME': 'SUNDANCE'}
# {'avg(LAND_SIZE_SF)': 6356.18082788671, 'COMM_NAME': 'SUNNYSIDE'}
# {'avg(LAND_SIZE_SF)': 3499.04953145917, 'COMM_NAME': 'TARADALE'}
# {'avg(LAND_SIZE_SF)': 4489.346153846154, 'COMM_NAME': 'TEMPLE'}
# {'avg(LAND_SIZE_SF)': 6130.874867444327, 'COMM_NAME': 'THORNCLIFFE'}
# {'avg(LAND_SIZE_SF)': 4801.595070422535, 'COMM_NAME': 'TUSCANY'}
# {'avg(LAND_SIZE_SF)': 4903.299595141701, 'COMM_NAME': 'TUXEDO PARK'}
# {'avg(LAND_SIZE_SF)': 7636.1604278074865, 'COMM_NAME': 'UNIVERSITY HEIGHTS'}
# {'avg(LAND_SIZE_SF)': 8632.313588850175, 'COMM_NAME': 'UPPER MOUNT ROYAL'}
# {'avg(LAND_SIZE_SF)': 5724.082269503546, 'COMM_NAME': 'VALLEY RIDGE'}
# {'avg(LAND_SIZE_SF)': 7444.560730593607, 'COMM_NAME': 'VARSITY'}
# {'avg(LAND_SIZE_SF)': 5202.62676056338, 'COMM_NAME': 'VISTA HEIGHTS'}
# {'avg(LAND_SIZE_SF)': 3344.16194790487, 'COMM_NAME': 'WALDEN'}
# {'avg(LAND_SIZE_SF)': 4713.202797202797, 'COMM_NAME': 'WEST HILLHURST'}
# {'avg(LAND_SIZE_SF)': 5407.403773584906, 'COMM_NAME': 'WEST SPRINGS'}
# {'avg(LAND_SIZE_SF)': 6118.1701570680625, 'COMM_NAME': 'WESTGATE'}
# {'avg(LAND_SIZE_SF)': 4587.55501618123, 'COMM_NAME': 'WHITEHORN'}
# {'avg(LAND_SIZE_SF)': 6255.573816155988, 'COMM_NAME': 'WILDWOOD'}
# {'avg(LAND_SIZE_SF)': 7344.277495769881, 'COMM_NAME': 'WILLOW PARK'}
# {'avg(LAND_SIZE_SF)': 5988.914814814815, 'COMM_NAME': 'WINDSOR PARK'}
# {'avg(LAND_SIZE_SF)': 5395.889352818372, 'COMM_NAME': 'WINSTON HEIGHTS/MOUNTVIEW'}
# {'avg(LAND_SIZE_SF)': 5738.776293823038, 'COMM_NAME': 'WOODBINE'}
# {'avg(LAND_SIZE_SF)': 5710.2067448680355, 'COMM_NAME': 'WOODLANDS'}
# True

# %% [markdown]
# I included this query as an option for future project work if we want to expand on our guiding questions if we have enough time after answering what we have for our guiding questions. Rather than purely looking at property assessment values and its relationship with demographics or crime, we can also take a look at average property sizes (in terms of square footage) for communities to see if there are any correlations present as well. I know many people do consider buying homes with specific property sizes so this could be an interesting thing to expand upon.
#
# We decided to use a top limit sq. footage of 15000 when doing searches because in this column, apartments sometimes take the sq. footage of the entire apartment complex rather than their own unit/space. So having this restriction ensures the rows that have the entire sq. footage of an apartment complex are not interfering with the average sq footage calculations. We also chose 15000 because we felt that no property within the bounds of calgary (that isnt a massive apartment complex) would be over these bounds, since while properties can be quite spacious in calgary, they are not the same size as farmland properties and so it would be quite difficult to be over the size of 15000 square feet.
